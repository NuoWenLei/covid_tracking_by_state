# %%
import json, requests
url_format = 'https://raw.githubusercontent.com/NuoWenLei/covid_tracking_by_state/main/state_data/alabama.csv'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"}
r = requests.get('https://raw.githubusercontent.com/NuoWenLei/covid_tracking_by_state/main/state_name_list.json', headers=headers)
r.text
# Out:
# '["alabama", "alaska", "american-samoa", "arizona", "arkansas", "california", "colorado", "connecticut", "delaware", "district-of-columbia", "florida", "georgia", "guam", "hawaii", "idaho", "illinois", "indiana", "iowa", "kansas", "kentucky", "louisiana", "maine", "maryland", "massachusetts", "michigan", "minnesota", "mississippi", "missouri", "montana", "nebraska", "nevada", "new-hampshire", "new-jersey", "new-mexico", "new-york", "north-carolina", "north-dakota", "northern-mariana-islands", "ohio", "oklahoma", "oregon", "pennsylvania", "puerto-rico", "rhode-island", "south-carolina", "south-dakota", "tennessee", "texas", "us-virgin-islands", "utah", "vermont", "virginia", "washington", "west-virginia", "wisconsin", "wyoming"]'

# %%
state_names = json.loads(r.text)

# %% [markdown]
# # Data Cleaning

# %%
from io import StringIO
import pandas as pd, numpy as np
state_pandas_dict_raw = {}

for state in state_names:
    print(state)
    r = requests.get('https://raw.githubusercontent.com/NuoWenLei/covid_tracking_by_state/main/state_data/{}.csv'.format(state), headers=headers)
    state_pandas_dict_raw[state] = pd.read_csv(StringIO(r.text))
# Out:
# alabama
# alaska
# american-samoa
# arizona
# arkansas
# california
# colorado
# connecticut
# delaware
# district-of-columbia
# florida
# georgia
# guam
# hawaii
# idaho
# illinois
# indiana
# iowa
# kansas
# kentucky
# louisiana
# maine
# maryland
# massachusetts
# michigan
# minnesota
# mississippi
# missouri
# montana
# nebraska
# nevada
# new-hampshire
# new-jersey
# new-mexico
# new-york
# north-carolina
# north-dakota
# northern-mariana-islands
# ohio
# oklahoma
# oregon
# pennsylvania
# puerto-rico
# rhode-island
# south-carolina
# south-dakota
# tennessee
# texas
# us-virgin-islands
# utah
# vermont
# virginia
# washington
# west-virginia
# wisconsin
# wyoming

# %%
state_pandas_dict_raw[state_names[0]]
# Out:
#            date state  ...  totalTestsViral  totalTestsViralIncrease
# 0    2021-03-04    AL  ...              NaN                        0
# 1    2021-03-03    AL  ...              NaN                        0
# 2    2021-03-02    AL  ...              NaN                        0
# 3    2021-03-01    AL  ...              NaN                        0
# 4    2021-02-28    AL  ...              NaN                        0
# ..          ...   ...  ...              ...                      ...
# 358  2020-03-11    AL  ...              NaN                        0
# 359  2020-03-10    AL  ...              NaN                        0
# 360  2020-03-09    AL  ...              NaN                        0
# 361  2020-03-08    AL  ...              NaN                        0
# 362  2020-03-07    AL  ...              NaN                        0
#
# [363 rows x 41 columns]

# %%
# find bad columns that is all nan
import matplotlib.pyplot as plt, seaborn as sns
state_pandas_dict = {}
nan_columns = []
all_columns = state_pandas_dict_raw[state].columns.values
must_columns = [i for i in all_columns if 'Increase' in i] + ['deathConfirmed', 'death']
good_states = []
print(must_columns)
for i, state in enumerate(state_names):
    state_pandas_dict[state] = state_pandas_dict_raw[state].drop(['state', 'date'], axis=1).astype('float64').fillna(0.0)
    print(state_pandas_dict[state].shape)
    for col in must_columns:
        if state_pandas_dict_raw[state][state_pandas_dict_raw[state][col].notna()].shape[0] < 200:
            print('State {} skipped due to insufficient data'.format(state))
            break
    else:
        good_states.append(state)
        for col in state_pandas_dict[state].columns.values:
            if state_pandas_dict[state][col].sum() == 0:
                if col not in nan_columns:
                    nan_columns.append(col)
print(len(nan_columns))
# Out:
# ['deathIncrease', 'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease', 'totalTestEncountersViralIncrease', 'totalTestResultsIncrease', 'totalTestsPeopleViralIncrease', 'totalTestsViralIncrease', 'deathConfirmed', 'death']
# (363, 39)
# (364, 39)
# (354, 39)
# State american-samoa skipped due to insufficient data
# (366, 39)
# (364, 39)
# State arkansas skipped due to insufficient data
# (366, 39)
# State california skipped due to insufficient data
# (366, 39)
# (370, 39)
# (364, 39)
# (365, 39)
# State district-of-columbia skipped due to insufficient data
# (401, 39)
# State florida skipped due to insufficient data
# (366, 39)
# State georgia skipped due to insufficient data
# (354, 39)
# State guam skipped due to insufficient data
# (366, 39)
# (363, 39)
# (366, 39)
# (372, 39)
# (364, 39)
# State iowa skipped due to insufficient data
# (364, 39)
# State kansas skipped due to insufficient data
# (364, 39)
# (363, 39)
# (363, 39)
# (365, 39)
# (408, 39)
# (369, 39)
# (364, 39)
# (363, 39)
# (363, 39)
# State missouri skipped due to insufficient data
# (363, 39)
# State montana skipped due to insufficient data
# (384, 39)
# State nebraska skipped due to insufficient data
# (365, 39)
# State nevada skipped due to insufficient data
# (366, 39)
# State new-hampshire skipped due to insufficient data
# (389, 39)
# (365, 39)
# State new-mexico skipped due to insufficient data
# (368, 39)
# State new-york skipped due to insufficient data
# (366, 39)
# (363, 39)
# State north-dakota skipped due to insufficient data
# (354, 39)
# State northern-mariana-islands skipped due to insufficient data
# (365, 39)
# (363, 39)
# State oklahoma skipped due to insufficient data
# (366, 39)
# State oregon skipped due to insufficient data
# (367, 39)
# State pennsylvania skipped due to insufficient data
# (354, 39)
# (369, 39)
# State rhode-island skipped due to insufficient data
# (366, 39)
# (363, 39)
# State south-dakota skipped due to insufficient data
# (365, 39)
# (367, 39)
# State texas skipped due to insufficient data
# (354, 39)
# State us-virgin-islands skipped due to insufficient data
# (363, 39)
# State utah skipped due to insufficient data
# (367, 39)
# (403, 39)
# (417, 39)
# (364, 39)
# (367, 39)
# (369, 39)
# State wyoming skipped due to insufficient data
# 31

# %%
# Drop bad columns
for i, state in enumerate(good_states):
    state_pandas_dict[state] = state_pandas_dict[state].drop(nan_columns, axis=1)

# %%
# Rename state columns with their state name included
good_cols = state_pandas_dict[good_states[0]].columns.values
for state in good_states:
    new_cols = ['{} - {}'.format(state, i) for i in good_cols]
    state_pandas_dict[state].columns = new_cols

# %%
state_pandas_dict[good_states[0]].head()
# Out:
#    alabama - death  ...  alabama - totalTestResultsIncrease
# 0          10094.0  ...                              5890.0
# 1          10029.0  ...                              9595.0
# 2           9991.0  ...                              3648.0
# 3           9931.0  ...                              1858.0
# 4           9929.0  ...                              3265.0
#
# [5 rows x 8 columns]

# %%
state_pandas_dict[good_states[0]].shape
# Out:
# (363, 8)

# %%
arr_lengths = []
for state in good_states:
    print('{}: {}'.format(state, state_pandas_dict[state].shape[0]))
    arr_lengths.append(state_pandas_dict[state].shape[0])
min_length = np.array(arr_lengths).min()
min_length
# Out:
# alabama: 363
# alaska: 364
# arizona: 366
# colorado: 366
# connecticut: 370
# delaware: 364
# hawaii: 366
# idaho: 363
# illinois: 366
# indiana: 372
# kentucky: 364
# louisiana: 363
# maine: 363
# maryland: 365
# massachusetts: 408
# michigan: 369
# minnesota: 364
# mississippi: 363
# new-jersey: 389
# north-carolina: 366
# ohio: 365
# puerto-rico: 354
# south-carolina: 366
# tennessee: 365
# vermont: 367
# virginia: 403
# washington: 417
# west-virginia: 364
# wisconsin: 367
# 354

# %%
for state in good_states:
    state_pandas_dict[state] = state_pandas_dict[state].head(min_length)
print(state_pandas_dict[good_states[0]].shape)
# Out:
# (354, 8)

# %% [markdown]
# # Visualize Death Data per State

# %%
death_data = {'date':state_pandas_dict_raw[good_states[0]].head(min_length)['date'].values}
plt.figure()
for state in good_states:
    death_data[state] = state_pandas_dict_raw[state].sort_values('date', ascending=True).head(min_length)['death'].fillna(0).values
death_df = pd.DataFrame(death_data)
fig, ax = plt.subplots()
sns.lineplot(x='date', y='value', hue='variable', data=pd.melt(death_df, ['date']))
plt.legend(title='legend', bbox_to_anchor=(1.05, 1), loc='upper left')
every_nth = 30
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if n % every_nth != 0:
        label.set_visible(False)
plt.xticks(rotation=-30)
plt.ylabel('deaths')
plt.show()

# %% [markdown]
# # Find Correlation Array

# %% [markdown]
# ## Try With first of state_names

# %%
df_dict_by_col = dict((col, state_pandas_dict[state_names[0]][col].values) for col in state_pandas_dict[state_names[0]].columns.values)

# %%
df_keys = df_dict_by_col.keys()

corr_data = []
for key0 in df_keys:
    key_row = []
    for key1 in df_keys:
        key_row.append(np.corrcoef(df_dict_by_col[key0], df_dict_by_col[key1])[1,0])
    corr_data.append(key_row)
corr_np = np.float64(corr_data)
corr_np
# Out:
# array([[1.        , 0.99628253, 0.51948179, 0.52389465, 0.97544758,
#         0.44213999, 0.93403598, 0.1507257 ],
#        [0.99628253, 1.        , 0.5129809 , 0.56338023, 0.98333664,
#         0.48379468, 0.95902426, 0.18056535],
#        [0.51948179, 0.5129809 , 1.        , 0.42919816, 0.5351837 ,
#         0.45838197, 0.48158829, 0.17382066],
#        [0.52389465, 0.56338023, 0.42919816, 1.        , 0.66935429,
#         0.83935024, 0.69777342, 0.37174191],
#        [0.97544758, 0.98333664, 0.5351837 , 0.66935429, 1.        ,
#         0.57734761, 0.97508886, 0.19486688],
#        [0.44213999, 0.48379468, 0.45838197, 0.83935024, 0.57734761,
#         1.        , 0.6287938 , 0.45762283],
#        [0.93403598, 0.95902426, 0.48158829, 0.69777342, 0.97508886,
#         0.6287938 , 1.        , 0.26102342],
#        [0.1507257 , 0.18056535, 0.17382066, 0.37174191, 0.19486688,
#         0.45762283, 0.26102342, 1.        ]])

# %%
corr_df = pd.DataFrame(corr_np)
corr_df
# Out:
#           0         1         2  ...         5         6         7
# 0  1.000000  0.996283  0.519482  ...  0.442140  0.934036  0.150726
# 1  0.996283  1.000000  0.512981  ...  0.483795  0.959024  0.180565
# 2  0.519482  0.512981  1.000000  ...  0.458382  0.481588  0.173821
# 3  0.523895  0.563380  0.429198  ...  0.839350  0.697773  0.371742
# 4  0.975448  0.983337  0.535184  ...  0.577348  0.975089  0.194867
# 5  0.442140  0.483795  0.458382  ...  1.000000  0.628794  0.457623
# 6  0.934036  0.959024  0.481588  ...  0.628794  1.000000  0.261023
# 7  0.150726  0.180565  0.173821  ...  0.457623  0.261023  1.000000
#
# [8 rows x 8 columns]

# %%
state_pandas_dict[state_names[0]].columns.shape
# Out:
# (8,)

# %%
def get_corr_list(pointers, corr_np):
    ordered_ls_left = [pointers[0]]
    ordered_ls_right = [pointers[1]]
    corr_ls_sum = 0


    visited = set(pointers.copy())
    all_cols = corr_np.shape[0]

    # Find highest unvisited correlated element
    def get_max(p, visits): 
        # print(p)
        s = sorted(list(enumerate(corr_np[p])),key=lambda x: x[1], reverse=True)
        for item in s:
            if item[0] == i or item[0] in visits:
                continue
            return item
        

    while len(visited) < all_cols:
        # print(pointers)
        val = get_max(pointers[0], visited)
        if val is None:
            break
        pointers[0], corr_val = val
        visited.add(pointers[0])
        ordered_ls_left.append(pointers[0])
        corr_ls_sum += corr_val
        
        val = get_max(pointers[1], visited)
        if val is None:
            break
        pointers[1], corr_val = val
        visited.add(pointers[1])
        ordered_ls_right.append(pointers[1])
        corr_ls_sum += corr_val

    ordered_ls = ordered_ls_left + list(reversed(ordered_ls_right))
    print(len(ordered_ls))
    print(corr_ls_sum)
    return ordered_ls, corr_ls_sum

# %%
def get_corr_list_v2(corr_np):
    pointer = 0
    ordered_ls = [0]
    visited = set([0])
    all_cols = corr_np.shape[0]
    corr_val_dict = {}
    def get_max(p, visits): 
        # print(p)
        s = sorted(list(enumerate(corr_np[p])),key=lambda x: x[1], reverse=True)
        for item in s:
            if item[0] == p or item[0] in visits:
                continue
            return item


    while len(visited) < all_cols:
        val = get_max(pointer, visited)
        if val is None:
            break
        new_pointer, corr_val = val
        visited.add(new_pointer)
        ordered_ls.append(new_pointer)
        corr_val_dict['{}-{}'.format(pointer, new_pointer)] = corr_val
        pointer = new_pointer
    #Complete circle by routing last pointer to first pointer, which is 0
    corr_val_dict['{}-{}'.format(pointer, 0)] = corr_np[pointer, 0]


    return corr_val_dict, ordered_ls

# %%
def get_corr_np(df):
    df_dict_by_col = dict((col, df[col].values) for col in df.columns.values)
    df_keys = df_dict_by_col.keys()
    corr_data = []
    for key0 in df_keys:
        key_row = []
        for key1 in df_keys:
            key_row.append(np.corrcoef(df_dict_by_col[key0], df_dict_by_col[key1])[1,0])
        corr_data.append(key_row)
    corr_np = np.float64(corr_data)
    return corr_np

# %%
def corr_list_by_df(df):
    df_dict_by_col = dict((col, df[col].values) for col in df.columns.values)
    df_keys = df_dict_by_col.keys()
    corr_data = []
    for key0 in df_keys:
        key_row = []
        for key1 in df_keys:
            key_row.append(np.corrcoef(df_dict_by_col[key0], df_dict_by_col[key1])[1,0])
        corr_data.append(key_row)
    corr_np = np.float64(corr_data)
    all_ordered_ls = []
    corr_sum_list = []
    for i in range(corr_np.shape[0]):
        for j in range(i+1, corr_np.shape[1]):
            ls, corr_sum = get_corr_list([i, j], corr_np)
            all_ordered_ls.append(ls)
            corr_sum_list.append(corr_sum)
    corr_sum_np = np.array(corr_sum_list)
    best_ordered_ls = all_ordered_ls[np.argmax(corr_sum_np)]
    print(np.max(corr_sum_np))
    print(best_ordered_ls)
    return best_ordered_ls, corr_np

# %%
# Create full df by combining data for all 
full_df = state_pandas_dict[good_states[0]].copy()
for state in good_states[1:]:
    for col in state_pandas_dict[state].columns.values:
        full_df[col] = state_pandas_dict[state][col].values
full_df.shape
# Out:
# (354, 232)

# %%
full_order_dict, circle_order = get_corr_list_v2(get_corr_np(full_df))

# %%
circle_order
# Out:
# [0,
#  1,
#  16,
#  17,
#  176,
#  177,
#  136,
#  94,
#  142,
#  190,
#  126,
#  230,
#  166,
#  70,
#  38,
#  102,
#  198,
#  118,
#  78,
#  222,
#  30,
#  56,
#  57,
#  172,
#  169,
#  168,
#  110,
#  158,
#  206,
#  150,
#  214,
#  46,
#  22,
#  182,
#  185,
#  156,
#  204,
#  80,
#  81,
#  152,
#  153,
#  140,
#  4,
#  188,
#  212,
#  225,
#  224,
#  76,
#  28,
#  124,
#  12,
#  132,
#  68,
#  60,
#  14,
#  134,
#  86,
#  54,
#  52,
#  48,
#  49,
#  184,
#  217,
#  216,
#  220,
#  164,
#  8,
#  84,
#  44,
#  36,
#  116,
#  148,
#  72,
#  73,
#  108,
#  128,
#  129,
#  64,
#  24,
#  25,
#  65,
#  105,
#  104,
#  40,
#  41,
#  112,
#  32,
#  145,
#  144,
#  113,
#  89,
#  88,
#  201,
#  200,
#  208,
#  92,
#  180,
#  20,
#  97,
#  96,
#  100,
#  196,
#  192,
#  120,
#  121,
#  161,
#  160,
#  6,
#  62,
#  137,
#  174,
#  33,
#  228,
#  155,
#  3,
#  187,
#  219,
#  83,
#  163,
#  75,
#  131,
#  29,
#  69,
#  227,
#  11,
#  59,
#  77,
#  221,
#  109,
#  211,
#  99,
#  205,
#  203,
#  43,
#  107,
#  106,
#  115,
#  147,
#  35,
#  114,
#  146,
#  34,
#  37,
#  125,
#  127,
#  171,
#  167,
#  71,
#  79,
#  31,
#  223,
#  159,
#  111,
#  207,
#  119,
#  103,
#  231,
#  61,
#  229,
#  13,
#  133,
#  135,
#  165,
#  85,
#  157,
#  181,
#  183,
#  197,
#  117,
#  149,
#  45,
#  101,
#  218,
#  5,
#  141,
#  139,
#  179,
#  19,
#  21,
#  23,
#  47,
#  189,
#  191,
#  9,
#  193,
#  209,
#  63,
#  7,
#  58,
#  226,
#  39,
#  186,
#  82,
#  154,
#  2,
#  18,
#  138,
#  98,
#  195,
#  91,
#  90,
#  93,
#  95,
#  130,
#  27,
#  123,
#  67,
#  66,
#  26,
#  122,
#  194,
#  170,
#  213,
#  173,
#  199,
#  55,
#  53,
#  51,
#  178,
#  202,
#  42,
#  210,
#  74,
#  215,
#  151,
#  143,
#  87,
#  15,
#  10,
#  162,
#  50,
#  175]

# %%
def best_ord_from_circle(d, circle):
    items = sorted(d.items(), key=lambda x: x[1], reverse=True)
    start, end = items[-1][0].split('-')
    start_point, end_point = circle.index(int(start)), circle.index(int(end))

    if end_point < start_point:
        return circle
    return list(reversed(circle[:circle.index(start)+1])) + circle[circle.index(end):]

# %%
full_order_v2 = best_ord_from_circle(full_order_dict, circle_order)
len(full_order_v2)
# Out:
# 232

# %%
# Manually Entering Here because running the function takes too long
full_order = [28, 124, 224, 225, 68, 30, 78, 222, 182, 185, 156, 184, 118, 84, 8, 76, 164, 220, 216, 217, 44, 36, 96, 97, 100, 196, 80, 81, 152, 153, 136, 94, 142, 190, 62, 6, 200, 201, 208, 137, 88, 89, 104, 105, 41, 40, 121, 120, 148, 160, 20, 12, 48, 49, 52, 119, 83, 163, 75, 219, 187, 3, 155, 99, 43, 107, 149, 197, 181, 183, 47, 111, 79, 77, 221, 109, 45, 165, 27, 123, 67, 66, 26, 130, 85, 223, 186, 218, 101, 157, 154, 18, 82, 2, 138, 98, 58, 173, 9, 193, 191, 189, 135, 226, 194, 74, 162, 151, 178, 202, 115, 114, 175, 210, 143, 50, 42, 215, 10, 15, 87, 7, 63, 51, 53, 55, 199, 39, 170, 125, 127, 95, 93, 90, 91, 122, 37, 34, 146, 147, 106, 35, 195, 117, 213, 207, 103, 209, 139, 141, 5, 61, 171, 231, 229, 133, 13, 59, 11, 131, 227, 69, 29, 31, 167, 71, 159, 23, 21, 19, 179, 33, 113, 112, 174, 145, 144, 32, 203, 211, 205, 192, 116, 161, 72, 73, 25, 65, 64, 24, 129, 128, 108, 92, 177, 176, 17, 16, 1, 0, 212, 204, 180, 22, 14, 134, 214, 206, 198, 102, 38, 169, 168, 54, 86, 230, 126, 166, 70, 110, 158, 150, 46, 140, 4, 188, 56, 57, 172, 60, 228, 132]

# %%
#full_order, full_corr = corr_list_by_df(full_df)

# %%
test_order, test_corr = corr_list_by_df(state_pandas_dict['alabama'])
# Out:
# 8
# 4.119440919647699
# 8
# 4.160380490760433
# 8
# 4.24397033141963
# 8
# 4.050366399826602
# 8
# 4.312949954532416
# 8
# 3.998920208754184
# 8
# 4.680879255423979
# 8
# 4.135392208751277
# 8
# 4.236081277433167
# 8
# 4.010880817841161
# 8
# 4.305060900545953
# 8
# 3.959434626768743
# 8
# 4.672990201437514
# 8
# 4.243970331419631
# 8
# 4.000770338509906
# 8
# 4.312949954532416
# 8
# 3.846917672464898
# 8
# 4.509549363271225
# 8
# 4.080077193362879
# 8
# 3.873299462086321
# 8
# 3.937387954743997
# 8
# 4.125174009581941
# 8
# 4.297248037975223
# 8
# 4.013405535677349
# 8
# 4.63982637505258
# 8
# 4.016973505712936
# 8
# 4.217180694992925
# 8
# 4.680879255423979
# 4.680879255423979
# [0, 1, 4, 6, 2, 3, 5, 7]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
full_np = scaler.fit_transform(full_df)

# %%
test_full_df = pd.DataFrame(full_np)
img_np = test_full_df[full_order].values

# %%
horizontal_img_np = np.swapaxes(img_np,0,1)

# %%
horizontal_img_np[:, :7]*255
# Out:
# array([[255.        , 254.20412095, 253.58261659, ..., 252.22060893,
#         251.72517275, 250.98054572],
#        [255.        , 254.28291627, 253.61371661, ..., 252.23724553,
#         252.23724553, 251.67794377],
#        [255.        , 254.53191189, 253.84778311, ..., 252.55153911,
#         252.55153911, 252.01143745],
#        ...,
#        [255.        , 254.33098448, 253.77741855, ..., 253.300819  ,
#         252.95595038, 252.49415206],
#        [255.        , 254.6482821 , 254.32741665, ..., 253.94073265,
#         253.74286562, 253.38579997],
#        [255.        , 254.50799988, 254.10026786, ..., 253.54493581,
#         253.12411868, 252.69911432]])

# %%
from PIL import Image
im = Image.fromarray(horizontal_img_np[:, :128]*255, 'L')
im.show()

# %%
horizontal_img_np.shape
# Out:
# (232, 354)

# %% [markdown]
# # TODO: Make Predict Values and use time series data to split numpy array into hundreds of 232x128 images

# %%
#full_df.head()
y_val_columns = [i for i in full_df.columns.values if 'deathIncrease' in i]
y_val_columns
# Out:
# ['alabama - deathIncrease',
#  'alaska - deathIncrease',
#  'arizona - deathIncrease',
#  'colorado - deathIncrease',
#  'connecticut - deathIncrease',
#  'delaware - deathIncrease',
#  'hawaii - deathIncrease',
#  'idaho - deathIncrease',
#  'illinois - deathIncrease',
#  'indiana - deathIncrease',
#  'kentucky - deathIncrease',
#  'louisiana - deathIncrease',
#  'maine - deathIncrease',
#  'maryland - deathIncrease',
#  'massachusetts - deathIncrease',
#  'michigan - deathIncrease',
#  'minnesota - deathIncrease',
#  'mississippi - deathIncrease',
#  'new-jersey - deathIncrease',
#  'north-carolina - deathIncrease',
#  'ohio - deathIncrease',
#  'puerto-rico - deathIncrease',
#  'south-carolina - deathIncrease',
#  'tennessee - deathIncrease',
#  'vermont - deathIncrease',
#  'virginia - deathIncrease',
#  'washington - deathIncrease',
#  'west-virginia - deathIncrease',
#  'wisconsin - deathIncrease']

# %%
y_val = np.zeros(full_df.shape[0])
for col in y_val_columns:
    y_val += full_df[col].values
y_val
# Out:
# array([ 668., 1069.,  582.,  559.,  484.,  800.,  967., 1083., 1120.,
#        1042.,  456.,  602.,  807., 1003., 1221.,  980.,  533.,  371.,
#         427., 2008., 3692., 2012., 1670., 1207.,  591.,  543., 1119.,
#        1531., 3163., 1690., 1521.,  760.,  689., 1178., 1469., 1753.,
#        1753., 1819.,  621.,  725., 1609., 1603., 1764., 1762.,  848.,
#         578.,  789., 1563., 1428., 1688., 1811., 1929.,  729.,  869.,
#        1533., 1690., 2066., 1761., 1825.,  846.,  771., 1273.,  933.,
#        1421., 1929., 1767.,  851.,  662.,  931.,  593., 1287., 1673.,
#        1691.,  762.,  765., 1301., 1454., 1894., 1730., 1487.,  720.,
#         729., 1304., 1276., 1664., 1716., 1386.,  655.,  560., 1272.,
#        1280., 1571., 1562., 1452.,  605.,  420.,  664.,  868.,  661.,
#        1267., 1265.,  407.,  462.,  794.,  984., 1173., 1021.,  928.,
#         352.,  352.,  700.,  749.,  571.,  894.,  771.,  343.,  281.,
#         587.,  583.,  605.,  596.,  642.,  210.,  188.,  509.,  481.,
#         515.,  510.,  552.,  234.,  207.,  398.,  465.,  518.,  557.,
#         449.,  257.,  159.,  261.,  377.,  415.,  353.,  378.,  115.,
#         114.,  280.,  302.,  387.,  370.,  311.,  141.,  144.,  332.,
#         368.,  362.,  415.,  366.,  133.,  120.,  301.,  350.,  362.,
#         366.,  396.,  123.,  138.,  305.,  354.,  355.,  424.,  528.,
#         169.,  167.,  291.,  426.,  435.,  487.,  138.,  103.,  161.,
#         321.,  410.,  348.,  379.,  394.,  167.,  224.,  333.,  397.,
#         399.,  568.,  425.,  152.,  198.,  360.,  409.,  434.,  527.,
#         445.,  161.,  210.,  416.,  341.,  389.,  574.,  474.,  154.,
#         254.,  309.,  496.,  498.,  505.,  452.,  167.,  262.,  371.,
#         476.,  570.,  561.,  504.,  209.,  204.,  441.,  491.,  445.,
#         479.,  517.,  160.,  206.,  427.,  380.,  423.,  364.,  353.,
#         143.,  241.,  348.,  384.,  364.,  435.,  552.,  105.,  104.,
#         164.,  293.,  371.,  406.,  337.,  177.,  157.,  316.,  343.,
#         308.,  445.,  418.,  197.,  149.,  404.,  350.,  319.,  430.,
#         430.,  201.,  204.,  431.,  430.,  499.,  536.,  509.,  491.,
#         266.,  450.,  477.,  537.,  598.,  590.,  486.,  401.,  522.,
#         721.,  723.,  850.,  434.,  341.,  425.,  583.,  756.,  667.,
#         950.,  853.,  496.,  546.,  732.,  968., 1105., 1114.,  939.,
#         564.,  619.,  845., 1026., 1169., 1241., 1352.,  608.,  778.,
#         849., 1193., 1406., 1478., 1356.,  714.,  667.,  884., 1191.,
#        1247., 1259., 1339., 1057.,  775., 1003., 1120., 1281., 1419.,
#        1242.,  797.,  799., 1002.,  998., 1032.,  947.,  971.,  599.,
#         581.,  672.,  573.,  594.,  493.,  470.,  270.,  210.,  254.,
#         218.,  168.,  120.,  105.,   88.,   57.,   40.,   37.,   29.,
#          16.,   14.,   17.])

# %%
y_val.shape
# Out:
# (354,)

# %%
TIME_LENGTH = 128
TIME_TEST_LENGTH = 1
def get_x_y(data, predict_vals, batch_size, test_length):
    total_length = data.shape[1]
    useable_starts = total_length - test_length - batch_size
    images = []
    y = []
    for i in range(0, useable_starts):
        images.append(data[:, i:i+batch_size])
        y.append(predict_vals[i+batch_size:i+batch_size+test_length])
    images_np = np.array(images)
    return images_np.reshape((images_np.shape[0], images_np.shape[1], images_np.shape[2], 1)), np.array(y)

imgs, y_values = get_x_y(horizontal_img_np, y_val, TIME_LENGTH, TIME_TEST_LENGTH)
print(imgs.shape)
print(y_values.shape)
# Out:
# (225, 232, 128, 1)
# (225, 1)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv2D, Dense, LSTM, SimpleRNN, AveragePooling2D, Flatten, Dropout
from tensorflow.keras.models import Model, Sequential

X_train, X_test, y_train, y_test = train_test_split(imgs, y_values, train_size=0.8, random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (180, 232, 128, 1) (45, 232, 128, 1) (180, 1) (45, 1)

# %%
def get_corr_img_cnn_model(feature_length, time_length, pred_length):
    model = Sequential()
    model.add(Conv2D(128, (3,3), input_shape=(feature_length, time_length, 1), padding='same', activation='relu'))
    model.add(AveragePooling2D())
    model.add(Dropout(0.3))
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(AveragePooling2D())
    model.add(Dropout(0.3))
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(pred_length, activation='relu'))
    model.compile(
        loss='mse',
        optimizer='adam',
        metrics=['mse', 'mae']
    )
    print(model.summary())
    return model

model = get_corr_img_cnn_model(X_train.shape[1], TIME_LENGTH, TIME_TEST_LENGTH)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 232, 128, 128)     1280
# _________________________________________________________________
# average_pooling2d_9 (Average (None, 116, 64, 128)      0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 116, 64, 128)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 116, 64, 64)       73792
# _________________________________________________________________
# average_pooling2d_10 (Averag (None, 58, 32, 64)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 58, 32, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 118784)            0
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               11878500
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 11,953,673
# Trainable params: 11,953,673
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(X_train, y_train, epochs=3000)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 501/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 320.9458 - mse: 320.9458 - accuracy: 0.0000e+00 - mae: 13.9742
# Epoch 502/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 415.3817 - mse: 415.3817 - accuracy: 0.0000e+00 - mae: 15.6092
# Epoch 503/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 459.0712 - mse: 459.0712 - accuracy: 0.0000e+00 - mae: 16.5801
# Epoch 504/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 409.4633 - mse: 409.4633 - accuracy: 0.0000e+00 - mae: 15.9743
# Epoch 505/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 524.1968 - mse: 524.1968 - accuracy: 0.0000e+00 - mae: 17.3461
# Epoch 506/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 372.6476 - mse: 372.6476 - accuracy: 0.0000e+00 - mae: 14.8788
# Epoch 507/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 388.1817 - mse: 388.1817 - accuracy: 0.0000e+00 - mae: 15.1965
# Epoch 508/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 353.5333 - mse: 353.5333 - accuracy: 0.0000e+00 - mae: 15.0602
# Epoch 509/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 421.0208 - mse: 421.0208 - accuracy: 0.0000e+00 - mae: 16.0612
# Epoch 510/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 554.9333 - mse: 554.9333 - accuracy: 0.0000e+00 - mae: 17.8502
# Epoch 511/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 519.6388 - mse: 519.6388 - accuracy: 0.0000e+00 - mae: 17.8747
# Epoch 512/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 508.8607 - mse: 508.8607 - accuracy: 0.0000e+00 - mae: 17.7519
# Epoch 513/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 356.9242 - mse: 356.9242 - accuracy: 0.0000e+00 - mae: 14.4677
# Epoch 514/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 370.0246 - mse: 370.0246 - accuracy: 0.0000e+00 - mae: 14.9750
# Epoch 515/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 376.9013 - mse: 376.9013 - accuracy: 0.0000e+00 - mae: 14.9215
# Epoch 516/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 449.1201 - mse: 449.1201 - accuracy: 0.0000e+00 - mae: 16.7193
# Epoch 517/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 389.4680 - mse: 389.4680 - accuracy: 0.0000e+00 - mae: 15.6678
# Epoch 518/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 318.7155 - mse: 318.7155 - accuracy: 0.0000e+00 - mae: 13.8893
# Epoch 519/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 355.1991 - mse: 355.1991 - accuracy: 0.0000e+00 - mae: 14.6370
# Epoch 520/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 376.7852 - mse: 376.7852 - accuracy: 0.0000e+00 - mae: 14.4342
# Epoch 521/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 433.5635 - mse: 433.5635 - accuracy: 0.0000e+00 - mae: 15.8679
# Epoch 522/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 420.4369 - mse: 420.4369 - accuracy: 0.0000e+00 - mae: 15.8406
# Epoch 523/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 435.4886 - mse: 435.4886 - accuracy: 0.0000e+00 - mae: 16.0255
# Epoch 524/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 354.4317 - mse: 354.4317 - accuracy: 0.0000e+00 - mae: 14.5094
# Epoch 525/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 393.5534 - mse: 393.5534 - accuracy: 0.0000e+00 - mae: 15.5736
# Epoch 526/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 293.0566 - mse: 293.0566 - accuracy: 0.0000e+00 - mae: 13.5760
# Epoch 527/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 394.4186 - mse: 394.4186 - accuracy: 0.0000e+00 - mae: 15.5465
# Epoch 528/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 323.3527 - mse: 323.3527 - accuracy: 0.0000e+00 - mae: 13.1779
# Epoch 529/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 370.0254 - mse: 370.0254 - accuracy: 0.0000e+00 - mae: 14.4787
# Epoch 530/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 333.0356 - mse: 333.0356 - accuracy: 0.0000e+00 - mae: 13.8643
# Epoch 531/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 358.0238 - mse: 358.0238 - accuracy: 0.0000e+00 - mae: 14.1397
# Epoch 532/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 325.8648 - mse: 325.8648 - accuracy: 0.0000e+00 - mae: 14.4466
# Epoch 533/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 399.8278 - mse: 399.8278 - accuracy: 0.0000e+00 - mae: 15.3173
# Epoch 534/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 395.9131 - mse: 395.9131 - accuracy: 0.0000e+00 - mae: 14.4948
# Epoch 535/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 443.5430 - mse: 443.5430 - accuracy: 0.0000e+00 - mae: 15.5022
# Epoch 536/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 335.9401 - mse: 335.9401 - accuracy: 0.0000e+00 - mae: 14.6274
# Epoch 537/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 439.7336 - mse: 439.7336 - accuracy: 0.0000e+00 - mae: 14.7367
# Epoch 538/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 354.2654 - mse: 354.2654 - accuracy: 0.0000e+00 - mae: 14.8130
# Epoch 539/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 517.7324 - mse: 517.7324 - accuracy: 0.0000e+00 - mae: 16.9948
# Epoch 540/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 473.4546 - mse: 473.4546 - accuracy: 0.0000e+00 - mae: 17.9078
# Epoch 541/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 506.5886 - mse: 506.5886 - accuracy: 0.0000e+00 - mae: 17.2344
# Epoch 542/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 313.9539 - mse: 313.9539 - accuracy: 0.0000e+00 - mae: 13.3239
# Epoch 543/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 261.9134 - mse: 261.9134 - accuracy: 0.0000e+00 - mae: 12.1054
# Epoch 544/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 256.6680 - mse: 256.6680 - accuracy: 0.0000e+00 - mae: 12.4503
# Epoch 545/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 356.9198 - mse: 356.9198 - accuracy: 0.0000e+00 - mae: 14.6559
# Epoch 546/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 327.2561 - mse: 327.2561 - accuracy: 0.0000e+00 - mae: 14.1193
# Epoch 547/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 333.6181 - mse: 333.6181 - accuracy: 0.0000e+00 - mae: 14.6820
# Epoch 548/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 421.3666 - mse: 421.3666 - accuracy: 0.0000e+00 - mae: 15.5170
# Epoch 549/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 261.5176 - mse: 261.5176 - accuracy: 0.0000e+00 - mae: 12.5117
# Epoch 550/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 360.5749 - mse: 360.5749 - accuracy: 0.0000e+00 - mae: 14.0189
# Epoch 551/3000
# 6/6 [==============================] - 0s 69ms/step - loss: 292.7426 - mse: 292.7426 - accuracy: 0.0000e+00 - mae: 12.9633
# Epoch 552/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 461.5452 - mse: 461.5452 - accuracy: 0.0000e+00 - mae: 16.0158
# Epoch 553/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 500.8000 - mse: 500.8000 - accuracy: 0.0000e+00 - mae: 16.9281
# Epoch 554/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 414.7789 - mse: 414.7789 - accuracy: 0.0000e+00 - mae: 15.8457
# Epoch 555/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 402.2165 - mse: 402.2165 - accuracy: 0.0000e+00 - mae: 15.5246
# Epoch 556/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 321.6295 - mse: 321.6295 - accuracy: 0.0000e+00 - mae: 13.6387
# Epoch 557/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 372.1877 - mse: 372.1877 - accuracy: 0.0000e+00 - mae: 14.8176
# Epoch 558/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 339.3135 - mse: 339.3135 - accuracy: 0.0000e+00 - mae: 14.2808
# Epoch 559/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 341.5320 - mse: 341.5320 - accuracy: 0.0000e+00 - mae: 14.3495
# Epoch 560/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 429.7294 - mse: 429.7294 - accuracy: 0.0000e+00 - mae: 15.3054
# Epoch 561/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 312.8155 - mse: 312.8155 - accuracy: 0.0000e+00 - mae: 13.5875
# Epoch 562/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 492.5259 - mse: 492.5259 - accuracy: 0.0000e+00 - mae: 15.8504
# Epoch 563/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 416.1231 - mse: 416.1231 - accuracy: 0.0000e+00 - mae: 15.2768
# Epoch 564/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 527.9274 - mse: 527.9274 - accuracy: 0.0000e+00 - mae: 17.0808
# Epoch 565/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 447.4062 - mse: 447.4062 - accuracy: 0.0000e+00 - mae: 16.2395
# Epoch 566/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 454.7088 - mse: 454.7087 - accuracy: 0.0000e+00 - mae: 16.0091
# Epoch 567/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 278.3539 - mse: 278.3539 - accuracy: 0.0000e+00 - mae: 13.2133
# Epoch 568/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 430.4791 - mse: 430.4791 - accuracy: 0.0000e+00 - mae: 15.0260
# Epoch 569/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 566.4091 - mse: 566.4091 - accuracy: 0.0000e+00 - mae: 18.6393
# Epoch 570/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 447.8252 - mse: 447.8252 - accuracy: 0.0000e+00 - mae: 16.5290
# Epoch 571/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 484.0796 - mse: 484.0796 - accuracy: 0.0000e+00 - mae: 16.8340
# Epoch 572/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 475.2154 - mse: 475.2154 - accuracy: 0.0000e+00 - mae: 16.5579
# Epoch 573/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 395.4956 - mse: 395.4956 - accuracy: 0.0000e+00 - mae: 15.0558
# Epoch 574/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 374.9808 - mse: 374.9808 - accuracy: 0.0000e+00 - mae: 15.1083
# Epoch 575/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 330.4199 - mse: 330.4199 - accuracy: 0.0000e+00 - mae: 13.5452
# Epoch 576/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 333.0169 - mse: 333.0169 - accuracy: 0.0000e+00 - mae: 14.0108
# Epoch 577/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 250.0936 - mse: 250.0936 - accuracy: 0.0000e+00 - mae: 12.2514
# Epoch 578/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 420.2265 - mse: 420.2265 - accuracy: 0.0000e+00 - mae: 15.9067
# Epoch 579/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 300.0101 - mse: 300.0101 - accuracy: 0.0000e+00 - mae: 12.9510
# Epoch 580/3000
# 6/6 [==============================] - 0s 69ms/step - loss: 293.8309 - mse: 293.8309 - accuracy: 0.0000e+00 - mae: 12.9742
# Epoch 581/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 296.5863 - mse: 296.5863 - accuracy: 0.0000e+00 - mae: 12.8803
# Epoch 582/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 548.4420 - mse: 548.4420 - accuracy: 0.0000e+00 - mae: 17.1593
# Epoch 583/3000
# 6/6 [==============================] - 0s 69ms/step - loss: 373.1621 - mse: 373.1621 - accuracy: 0.0000e+00 - mae: 14.8066
# Epoch 584/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 379.0327 - mse: 379.0327 - accuracy: 0.0000e+00 - mae: 14.4370
# Epoch 585/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 394.0388 - mse: 394.0388 - accuracy: 0.0000e+00 - mae: 14.9465
# Epoch 586/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 492.8382 - mse: 492.8382 - accuracy: 0.0000e+00 - mae: 16.6236
# Epoch 587/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 631.4562 - mse: 631.4562 - accuracy: 0.0000e+00 - mae: 20.3153
# Epoch 588/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 516.6116 - mse: 516.6116 - accuracy: 0.0000e+00 - mae: 17.6430
# Epoch 589/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 641.2558 - mse: 641.2558 - accuracy: 0.0000e+00 - mae: 19.2737
# Epoch 590/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 751.8582 - mse: 751.8582 - accuracy: 0.0000e+00 - mae: 20.7871
# Epoch 591/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 537.4335 - mse: 537.4335 - accuracy: 0.0000e+00 - mae: 18.6397
# Epoch 592/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 405.2754 - mse: 405.2754 - accuracy: 0.0000e+00 - mae: 15.4020
# Epoch 593/3000
# 6/6 [==============================] - 0s 69ms/step - loss: 494.4816 - mse: 494.4816 - accuracy: 0.0000e+00 - mae: 16.1742
# Epoch 594/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 481.7154 - mse: 481.7154 - accuracy: 0.0000e+00 - mae: 16.9861
# Epoch 595/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 290.4696 - mse: 290.4696 - accuracy: 0.0000e+00 - mae: 13.5345
# Epoch 596/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 279.6479 - mse: 279.6479 - accuracy: 0.0000e+00 - mae: 12.6857
# Epoch 597/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 305.6509 - mse: 305.6509 - accuracy: 0.0000e+00 - mae: 12.9943
# Epoch 598/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 309.8757 - mse: 309.8757 - accuracy: 0.0000e+00 - mae: 13.7938
# Epoch 599/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 254.3632 - mse: 254.3632 - accuracy: 0.0000e+00 - mae: 12.4313
# Epoch 600/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 280.6459 - mse: 280.6459 - accuracy: 0.0000e+00 - mae: 12.6237
# Epoch 601/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 305.4052 - mse: 305.4052 - accuracy: 0.0000e+00 - mae: 13.4881
# Epoch 602/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 362.3343 - mse: 362.3343 - accuracy: 0.0000e+00 - mae: 14.5741
# Epoch 603/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 397.7878 - mse: 397.7878 - accuracy: 0.0000e+00 - mae: 15.3554
# Epoch 604/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 388.0437 - mse: 388.0437 - accuracy: 0.0000e+00 - mae: 14.9847
# Epoch 605/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 320.2985 - mse: 320.2985 - accuracy: 0.0000e+00 - mae: 14.0083
# Epoch 606/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 270.3444 - mse: 270.3444 - accuracy: 0.0000e+00 - mae: 12.4762
# Epoch 607/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 234.2790 - mse: 234.2790 - accuracy: 0.0000e+00 - mae: 12.1139
# Epoch 608/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 320.0391 - mse: 320.0391 - accuracy: 0.0000e+00 - mae: 14.1734
# Epoch 609/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 285.9710 - mse: 285.9710 - accuracy: 0.0000e+00 - mae: 12.9168
# Epoch 610/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 291.7444 - mse: 291.7444 - accuracy: 0.0000e+00 - mae: 13.3210
# Epoch 611/3000
# 6/6 [==============================] - 0s 69ms/step - loss: 311.4854 - mse: 311.4854 - accuracy: 0.0000e+00 - mae: 13.1102
# Epoch 612/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 325.1964 - mse: 325.1964 - accuracy: 0.0000e+00 - mae: 13.6174
# Epoch 613/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 267.9577 - mse: 267.9577 - accuracy: 0.0000e+00 - mae: 12.6930
# Epoch 614/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 280.7981 - mse: 280.7981 - accuracy: 0.0000e+00 - mae: 13.0113
# Epoch 615/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 268.1284 - mse: 268.1284 - accuracy: 0.0000e+00 - mae: 12.5374
# Epoch 616/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 254.7366 - mse: 254.7366 - accuracy: 0.0000e+00 - mae: 12.1783
# Epoch 617/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 259.0151 - mse: 259.0151 - accuracy: 0.0000e+00 - mae: 12.6431
# Epoch 618/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 262.7705 - mse: 262.7705 - accuracy: 0.0000e+00 - mae: 12.5288
# Epoch 619/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 269.2550 - mse: 269.2550 - accuracy: 0.0000e+00 - mae: 12.8587
# Epoch 620/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 306.2299 - mse: 306.2299 - accuracy: 0.0000e+00 - mae: 13.4091
# Epoch 621/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 235.1521 - mse: 235.1521 - accuracy: 0.0000e+00 - mae: 12.0282
# Epoch 622/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 268.4577 - mse: 268.4577 - accuracy: 0.0000e+00 - mae: 13.0312
# Epoch 623/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 259.2278 - mse: 259.2278 - accuracy: 0.0000e+00 - mae: 12.5779
# Epoch 624/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 315.2482 - mse: 315.2482 - accuracy: 0.0000e+00 - mae: 13.1946
# Epoch 625/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 312.6226 - mse: 312.6226 - accuracy: 0.0000e+00 - mae: 13.3499
# Epoch 626/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 415.8637 - mse: 415.8637 - accuracy: 0.0000e+00 - mae: 15.6251
# Epoch 627/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 290.8326 - mse: 290.8326 - accuracy: 0.0000e+00 - mae: 13.5430
# Epoch 628/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 350.1697 - mse: 350.1697 - accuracy: 0.0000e+00 - mae: 14.3926
# Epoch 629/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 322.1807 - mse: 322.1807 - accuracy: 0.0000e+00 - mae: 14.3864
# Epoch 630/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 289.4852 - mse: 289.4852 - accuracy: 0.0000e+00 - mae: 12.5629
# Epoch 631/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 358.2437 - mse: 358.2437 - accuracy: 0.0000e+00 - mae: 14.8795
# Epoch 632/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 326.2630 - mse: 326.2630 - accuracy: 0.0000e+00 - mae: 13.9297
# Epoch 633/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 391.4350 - mse: 391.4350 - accuracy: 0.0000e+00 - mae: 14.4896
# Epoch 634/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 353.7532 - mse: 353.7532 - accuracy: 0.0000e+00 - mae: 14.6467
# Epoch 635/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 330.5121 - mse: 330.5121 - accuracy: 0.0000e+00 - mae: 13.8480
# Epoch 636/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 306.0532 - mse: 306.0532 - accuracy: 0.0000e+00 - mae: 13.4056
# Epoch 637/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 424.6620 - mse: 424.6620 - accuracy: 0.0000e+00 - mae: 15.9129
# Epoch 638/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 290.5052 - mse: 290.5052 - accuracy: 0.0000e+00 - mae: 13.0069
# Epoch 639/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 203.6339 - mse: 203.6339 - accuracy: 0.0000e+00 - mae: 11.0507
# Epoch 640/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 240.5724 - mse: 240.5724 - accuracy: 0.0000e+00 - mae: 12.5391
# Epoch 641/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 328.0294 - mse: 328.0294 - accuracy: 0.0000e+00 - mae: 12.9826
# Epoch 642/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 471.0979 - mse: 471.0979 - accuracy: 0.0000e+00 - mae: 16.7486
# Epoch 643/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 611.4941 - mse: 611.4941 - accuracy: 0.0000e+00 - mae: 18.8466
# Epoch 644/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 400.8357 - mse: 400.8357 - accuracy: 0.0000e+00 - mae: 14.7784
# Epoch 645/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 427.2375 - mse: 427.2375 - accuracy: 0.0000e+00 - mae: 15.5832
# Epoch 646/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 318.1117 - mse: 318.1118 - accuracy: 0.0000e+00 - mae: 12.9631
# Epoch 647/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 416.9478 - mse: 416.9478 - accuracy: 0.0000e+00 - mae: 15.2911
# Epoch 648/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 284.4524 - mse: 284.4524 - accuracy: 0.0000e+00 - mae: 12.5292
# Epoch 649/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 277.0359 - mse: 277.0359 - accuracy: 0.0000e+00 - mae: 12.5589
# Epoch 650/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 223.7302 - mse: 223.7302 - accuracy: 0.0000e+00 - mae: 11.6950
# Epoch 651/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 264.0227 - mse: 264.0227 - accuracy: 0.0000e+00 - mae: 12.4249
# Epoch 652/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 268.0517 - mse: 268.0517 - accuracy: 0.0000e+00 - mae: 12.8165
# Epoch 653/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 247.9892 - mse: 247.9892 - accuracy: 0.0000e+00 - mae: 12.2250
# Epoch 654/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 308.2517 - mse: 308.2517 - accuracy: 0.0000e+00 - mae: 13.1834
# Epoch 655/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 414.1359 - mse: 414.1359 - accuracy: 0.0000e+00 - mae: 15.2413
# Epoch 656/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 413.4120 - mse: 413.4120 - accuracy: 0.0000e+00 - mae: 15.1780
# Epoch 657/3000
# 6/6 [==============================] - 0s 69ms/step - loss: 291.3604 - mse: 291.3604 - accuracy: 0.0000e+00 - mae: 12.9381
# Epoch 658/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 356.4926 - mse: 356.4926 - accuracy: 0.0000e+00 - mae: 14.4514
# Epoch 659/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 343.8423 - mse: 343.8423 - accuracy: 0.0000e+00 - mae: 13.8589
# Epoch 660/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 420.9741 - mse: 420.9741 - accuracy: 0.0000e+00 - mae: 15.7059
# Epoch 661/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 348.3296 - mse: 348.3296 - accuracy: 0.0000e+00 - mae: 13.4357
# Epoch 662/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 369.7052 - mse: 369.7052 - accuracy: 0.0000e+00 - mae: 13.2763
# Epoch 663/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 244.8281 - mse: 244.8281 - accuracy: 0.0000e+00 - mae: 12.0203
# Epoch 664/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 226.3981 - mse: 226.3981 - accuracy: 0.0000e+00 - mae: 11.1498
# Epoch 665/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 259.6453 - mse: 259.6453 - accuracy: 0.0000e+00 - mae: 12.3189
# Epoch 666/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 216.8474 - mse: 216.8474 - accuracy: 0.0000e+00 - mae: 11.4628
# Epoch 667/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 299.0706 - mse: 299.0706 - accuracy: 0.0000e+00 - mae: 13.6345
# Epoch 668/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 368.9060 - mse: 368.9060 - accuracy: 0.0000e+00 - mae: 14.7424
# Epoch 669/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 361.2713 - mse: 361.2713 - accuracy: 0.0000e+00 - mae: 14.3312
# Epoch 670/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 407.0185 - mse: 407.0185 - accuracy: 0.0000e+00 - mae: 15.6161
# Epoch 671/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 286.0791 - mse: 286.0791 - accuracy: 0.0000e+00 - mae: 12.8688
# Epoch 672/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 294.2977 - mse: 294.2977 - accuracy: 0.0000e+00 - mae: 13.7452
# Epoch 673/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 278.7876 - mse: 278.7876 - accuracy: 0.0000e+00 - mae: 13.1160
# Epoch 674/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 384.3304 - mse: 384.3304 - accuracy: 0.0000e+00 - mae: 15.2221
# Epoch 675/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 694.4123 - mse: 694.4123 - accuracy: 0.0000e+00 - mae: 21.5036
# Epoch 676/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 752.1110 - mse: 752.1110 - accuracy: 0.0000e+00 - mae: 19.7535
# Epoch 677/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 446.3464 - mse: 446.3464 - accuracy: 0.0000e+00 - mae: 16.8016
# Epoch 678/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 333.1337 - mse: 333.1337 - accuracy: 0.0000e+00 - mae: 13.8563
# Epoch 679/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 320.7246 - mse: 320.7246 - accuracy: 0.0000e+00 - mae: 13.6376
# Epoch 680/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 279.1465 - mse: 279.1465 - accuracy: 0.0000e+00 - mae: 13.2382
# Epoch 681/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 286.9015 - mse: 286.9015 - accuracy: 0.0000e+00 - mae: 12.6858
# Epoch 682/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 265.7007 - mse: 265.7006 - accuracy: 0.0000e+00 - mae: 12.4877
# Epoch 683/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 315.5680 - mse: 315.5680 - accuracy: 0.0000e+00 - mae: 13.5705
# Epoch 684/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 457.5115 - mse: 457.5115 - accuracy: 0.0000e+00 - mae: 16.7725
# Epoch 685/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 550.1052 - mse: 550.1052 - accuracy: 0.0000e+00 - mae: 18.1096
# Epoch 686/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 427.1528 - mse: 427.1528 - accuracy: 0.0000e+00 - mae: 14.9973
# Epoch 687/3000
# 6/6 [==============================] - 0s 69ms/step - loss: 373.4124 - mse: 373.4124 - accuracy: 0.0000e+00 - mae: 15.1043
# Epoch 688/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 285.4165 - mse: 285.4165 - accuracy: 0.0000e+00 - mae: 12.9423
# Epoch 689/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 266.4095 - mse: 266.4095 - accuracy: 0.0000e+00 - mae: 13.0023
# Epoch 690/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 231.1967 - mse: 231.1967 - accuracy: 0.0000e+00 - mae: 11.8308
# Epoch 691/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 219.3092 - mse: 219.3092 - accuracy: 0.0000e+00 - mae: 11.6673
# Epoch 692/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 366.5124 - mse: 366.5124 - accuracy: 0.0000e+00 - mae: 14.1701
# Epoch 693/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 614.6700 - mse: 614.6700 - accuracy: 0.0000e+00 - mae: 19.8477
# Epoch 694/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 699.1036 - mse: 699.1036 - accuracy: 0.0000e+00 - mae: 20.8499
# Epoch 695/3000
# 6/6 [==============================] - 0s 69ms/step - loss: 1298.7994 - mse: 1298.7994 - accuracy: 0.0000e+00 - mae: 27.3088
# Epoch 696/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 880.8734 - mse: 880.8734 - accuracy: 0.0000e+00 - mae: 23.8393
# Epoch 697/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 589.7400 - mse: 589.7400 - accuracy: 0.0000e+00 - mae: 18.2942
# Epoch 698/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 898.2498 - mse: 898.2498 - accuracy: 0.0000e+00 - mae: 21.8671
# Epoch 699/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 883.3311 - mse: 883.3311 - accuracy: 0.0000e+00 - mae: 22.7474
# Epoch 700/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 634.9005 - mse: 634.9005 - accuracy: 0.0000e+00 - mae: 18.4637
# Epoch 701/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 551.4356 - mse: 551.4356 - accuracy: 0.0000e+00 - mae: 16.6965
# Epoch 702/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 376.9083 - mse: 376.9083 - accuracy: 0.0000e+00 - mae: 14.6082
# Epoch 703/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 365.9596 - mse: 365.9596 - accuracy: 0.0000e+00 - mae: 15.0197
# Epoch 704/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 390.4682 - mse: 390.4682 - accuracy: 0.0000e+00 - mae: 15.0470
# Epoch 705/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 371.4398 - mse: 371.4398 - accuracy: 0.0000e+00 - mae: 14.9740
# Epoch 706/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 568.2760 - mse: 568.2760 - accuracy: 0.0000e+00 - mae: 16.7227
# Epoch 707/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 396.2995 - mse: 396.2995 - accuracy: 0.0000e+00 - mae: 15.4298
# Epoch 708/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 537.9497 - mse: 537.9497 - accuracy: 0.0000e+00 - mae: 17.4384
# Epoch 709/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 410.8586 - mse: 410.8586 - accuracy: 0.0000e+00 - mae: 16.1203
# Epoch 710/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 289.4237 - mse: 289.4237 - accuracy: 0.0000e+00 - mae: 13.2411
# Epoch 711/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 235.3747 - mse: 235.3747 - accuracy: 0.0000e+00 - mae: 11.8830
# Epoch 712/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 286.1747 - mse: 286.1747 - accuracy: 0.0000e+00 - mae: 12.2562
# Epoch 713/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 242.7772 - mse: 242.7772 - accuracy: 0.0000e+00 - mae: 11.6968
# Epoch 714/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 262.0059 - mse: 262.0059 - accuracy: 0.0000e+00 - mae: 12.1330
# Epoch 715/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 221.6223 - mse: 221.6223 - accuracy: 0.0000e+00 - mae: 12.1541
# Epoch 716/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 257.5701 - mse: 257.5701 - accuracy: 0.0000e+00 - mae: 12.3969
# Epoch 717/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 341.3463 - mse: 341.3463 - accuracy: 0.0000e+00 - mae: 13.5472
# Epoch 718/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 249.3776 - mse: 249.3776 - accuracy: 0.0000e+00 - mae: 11.8981
# Epoch 719/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 270.3522 - mse: 270.3522 - accuracy: 0.0000e+00 - mae: 12.1940
# Epoch 720/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 325.7468 - mse: 325.7468 - accuracy: 0.0000e+00 - mae: 13.9949
# Epoch 721/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 243.2451 - mse: 243.2451 - accuracy: 0.0000e+00 - mae: 12.0922
# Epoch 722/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 251.3416 - mse: 251.3416 - accuracy: 0.0000e+00 - mae: 12.1234
# Epoch 723/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 268.4766 - mse: 268.4766 - accuracy: 0.0000e+00 - mae: 11.8522
# Epoch 724/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 339.9664 - mse: 339.9664 - accuracy: 0.0000e+00 - mae: 13.4989
# Epoch 725/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 261.5649 - mse: 261.5649 - accuracy: 0.0000e+00 - mae: 12.6736
# Epoch 726/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 340.7137 - mse: 340.7137 - accuracy: 0.0000e+00 - mae: 13.7132
# Epoch 727/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 256.3621 - mse: 256.3621 - accuracy: 0.0000e+00 - mae: 11.7860
# Epoch 728/3000
# 6/6 [==============================] - 0s 69ms/step - loss: 303.6980 - mse: 303.6980 - accuracy: 0.0000e+00 - mae: 13.6321
# Epoch 729/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 234.3022 - mse: 234.3022 - accuracy: 0.0000e+00 - mae: 12.0941
# Epoch 730/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 302.4802 - mse: 302.4802 - accuracy: 0.0000e+00 - mae: 13.4386
# Epoch 731/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 242.5494 - mse: 242.5494 - accuracy: 0.0000e+00 - mae: 12.1398
# Epoch 732/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 246.8667 - mse: 246.8667 - accuracy: 0.0000e+00 - mae: 12.0031
# Epoch 733/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 230.9289 - mse: 230.9289 - accuracy: 0.0000e+00 - mae: 11.5200
# Epoch 734/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 266.0198 - mse: 266.0198 - accuracy: 0.0000e+00 - mae: 12.7298
# Epoch 735/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 301.3667 - mse: 301.3667 - accuracy: 0.0000e+00 - mae: 13.1751
# Epoch 736/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 264.4967 - mse: 264.4967 - accuracy: 0.0000e+00 - mae: 12.1200
# Epoch 737/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 296.6087 - mse: 296.6087 - accuracy: 0.0000e+00 - mae: 13.3114
# Epoch 738/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 237.9082 - mse: 237.9082 - accuracy: 0.0000e+00 - mae: 11.7412
# Epoch 739/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 241.5154 - mse: 241.5154 - accuracy: 0.0000e+00 - mae: 12.1082
# Epoch 740/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 237.8026 - mse: 237.8026 - accuracy: 0.0000e+00 - mae: 11.4396
# Epoch 741/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 284.5960 - mse: 284.5960 - accuracy: 0.0000e+00 - mae: 12.9472
# Epoch 742/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 288.0532 - mse: 288.0532 - accuracy: 0.0000e+00 - mae: 12.7757
# Epoch 743/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 305.0634 - mse: 305.0634 - accuracy: 0.0000e+00 - mae: 13.6414
# Epoch 744/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 246.9868 - mse: 246.9868 - accuracy: 0.0000e+00 - mae: 12.0743
# Epoch 745/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 362.9798 - mse: 362.9798 - accuracy: 0.0000e+00 - mae: 14.3353
# Epoch 746/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 274.7867 - mse: 274.7867 - accuracy: 0.0000e+00 - mae: 12.0734
# Epoch 747/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 319.3317 - mse: 319.3317 - accuracy: 0.0000e+00 - mae: 13.8628
# Epoch 748/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 493.1815 - mse: 493.1815 - accuracy: 0.0000e+00 - mae: 17.4764
# Epoch 749/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 269.8718 - mse: 269.8718 - accuracy: 0.0000e+00 - mae: 12.5549
# Epoch 750/3000
# 6/6 [==============================] - 0s 70ms/step - loss: 190.6699 - mse: 190.6699 - accuracy: 0.0000e+00 - mae: 10.9464
# Epoch 751/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 292.5392 - mse: 292.5392 - accuracy: 0.0000e+00 - mae: 13.0613
# Epoch 752/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 248.0577 - mse: 248.0577 - accuracy: 0.0000e+00 - mae: 12.0407
# Epoch 753/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 306.0544 - mse: 306.0544 - accuracy: 0.0000e+00 - mae: 13.2050
# Epoch 754/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 384.2253 - mse: 384.2253 - accuracy: 0.0000e+00 - mae: 13.9880
# Epoch 755/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 305.2125 - mse: 305.2125 - accuracy: 0.0000e+00 - mae: 12.6783
# Epoch 756/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 205.2977 - mse: 205.2977 - accuracy: 0.0000e+00 - mae: 10.9671
# Epoch 757/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 308.2759 - mse: 308.2759 - accuracy: 0.0000e+00 - mae: 13.0411
# Epoch 758/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 386.3944 - mse: 386.3944 - accuracy: 0.0000e+00 - mae: 14.4450
# Epoch 759/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 290.9789 - mse: 290.9789 - accuracy: 0.0000e+00 - mae: 12.9753
# Epoch 760/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 268.0670 - mse: 268.0670 - accuracy: 0.0000e+00 - mae: 12.3332
# Epoch 761/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 277.6260 - mse: 277.6260 - accuracy: 0.0000e+00 - mae: 12.5116
# Epoch 762/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 332.8194 - mse: 332.8194 - accuracy: 0.0000e+00 - mae: 13.6667
# Epoch 763/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 420.4297 - mse: 420.4297 - accuracy: 0.0000e+00 - mae: 16.3862
# Epoch 764/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 353.9657 - mse: 353.9657 - accuracy: 0.0000e+00 - mae: 14.3960
# Epoch 765/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 408.2639 - mse: 408.2639 - accuracy: 0.0000e+00 - mae: 14.9706
# Epoch 766/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 314.8430 - mse: 314.8430 - accuracy: 0.0000e+00 - mae: 14.1075
# Epoch 767/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 297.0230 - mse: 297.0230 - accuracy: 0.0000e+00 - mae: 12.8973
# Epoch 768/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 290.5490 - mse: 290.5490 - accuracy: 0.0000e+00 - mae: 13.2609
# Epoch 769/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 446.8582 - mse: 446.8582 - accuracy: 0.0000e+00 - mae: 15.5332
# Epoch 770/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 585.1779 - mse: 585.1779 - accuracy: 0.0000e+00 - mae: 18.4694
# Epoch 771/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 490.2466 - mse: 490.2466 - accuracy: 0.0000e+00 - mae: 16.9205
# Epoch 772/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 455.1364 - mse: 455.1364 - accuracy: 0.0000e+00 - mae: 16.0008
# Epoch 773/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 469.5392 - mse: 469.5392 - accuracy: 0.0000e+00 - mae: 17.4250
# Epoch 774/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 552.2072 - mse: 552.2072 - accuracy: 0.0000e+00 - mae: 17.7585
# Epoch 775/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 390.1238 - mse: 390.1238 - accuracy: 0.0000e+00 - mae: 14.2195
# Epoch 776/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 302.0864 - mse: 302.0864 - accuracy: 0.0000e+00 - mae: 13.4168
# Epoch 777/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 224.2490 - mse: 224.2490 - accuracy: 0.0000e+00 - mae: 12.0740
# Epoch 778/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 300.4648 - mse: 300.4648 - accuracy: 0.0000e+00 - mae: 13.2034
# Epoch 779/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 298.3121 - mse: 298.3121 - accuracy: 0.0000e+00 - mae: 12.6864
# Epoch 780/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 272.6857 - mse: 272.6857 - accuracy: 0.0000e+00 - mae: 12.3854
# Epoch 781/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 242.8203 - mse: 242.8203 - accuracy: 0.0000e+00 - mae: 11.4298
# Epoch 782/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 297.8098 - mse: 297.8098 - accuracy: 0.0000e+00 - mae: 12.3688
# Epoch 783/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 232.1693 - mse: 232.1693 - accuracy: 0.0000e+00 - mae: 12.2398
# Epoch 784/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 219.6675 - mse: 219.6675 - accuracy: 0.0000e+00 - mae: 11.4271
# Epoch 785/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 211.4777 - mse: 211.4777 - accuracy: 0.0000e+00 - mae: 10.9346
# Epoch 786/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 225.0035 - mse: 225.0035 - accuracy: 0.0000e+00 - mae: 11.4347
# Epoch 787/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 234.2700 - mse: 234.2700 - accuracy: 0.0000e+00 - mae: 11.6083
# Epoch 788/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 237.6812 - mse: 237.6812 - accuracy: 0.0000e+00 - mae: 11.2030
# Epoch 789/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 238.8403 - mse: 238.8403 - accuracy: 0.0000e+00 - mae: 11.9502
# Epoch 790/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 221.6770 - mse: 221.6770 - accuracy: 0.0000e+00 - mae: 11.3078
# Epoch 791/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 197.4867 - mse: 197.4867 - accuracy: 0.0000e+00 - mae: 10.6702
# Epoch 792/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 242.0923 - mse: 242.0923 - accuracy: 0.0000e+00 - mae: 11.3834
# Epoch 793/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 183.6483 - mse: 183.6483 - accuracy: 0.0000e+00 - mae: 9.9008
# Epoch 794/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 216.6417 - mse: 216.6417 - accuracy: 0.0000e+00 - mae: 11.3365
# Epoch 795/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 244.6818 - mse: 244.6818 - accuracy: 0.0000e+00 - mae: 11.5795
# Epoch 796/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 252.6155 - mse: 252.6155 - accuracy: 0.0000e+00 - mae: 12.4262
# Epoch 797/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 215.4384 - mse: 215.4384 - accuracy: 0.0000e+00 - mae: 11.0364
# Epoch 798/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 205.8597 - mse: 205.8597 - accuracy: 0.0000e+00 - mae: 11.3658
# Epoch 799/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 241.0025 - mse: 241.0025 - accuracy: 0.0000e+00 - mae: 11.7784
# Epoch 800/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 309.8913 - mse: 309.8913 - accuracy: 0.0000e+00 - mae: 12.6744
# Epoch 801/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 239.3971 - mse: 239.3971 - accuracy: 0.0000e+00 - mae: 11.7069
# Epoch 802/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 260.6445 - mse: 260.6445 - accuracy: 0.0000e+00 - mae: 11.8175
# Epoch 803/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 184.3280 - mse: 184.3280 - accuracy: 0.0000e+00 - mae: 10.5283
# Epoch 804/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 269.6327 - mse: 269.6327 - accuracy: 0.0000e+00 - mae: 12.5961
# Epoch 805/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 237.5863 - mse: 237.5863 - accuracy: 0.0000e+00 - mae: 12.1969
# Epoch 806/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 218.5899 - mse: 218.5899 - accuracy: 0.0000e+00 - mae: 11.3516
# Epoch 807/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 318.4384 - mse: 318.4384 - accuracy: 0.0000e+00 - mae: 14.0949
# Epoch 808/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 395.5234 - mse: 395.5234 - accuracy: 0.0000e+00 - mae: 14.4930
# Epoch 809/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 307.8433 - mse: 307.8433 - accuracy: 0.0000e+00 - mae: 13.0271
# Epoch 810/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 303.7823 - mse: 303.7823 - accuracy: 0.0000e+00 - mae: 12.9414
# Epoch 811/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 292.5505 - mse: 292.5505 - accuracy: 0.0000e+00 - mae: 13.3480
# Epoch 812/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 292.4755 - mse: 292.4755 - accuracy: 0.0000e+00 - mae: 12.8106
# Epoch 813/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 264.3236 - mse: 264.3236 - accuracy: 0.0000e+00 - mae: 12.4402
# Epoch 814/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 232.3115 - mse: 232.3115 - accuracy: 0.0000e+00 - mae: 11.0284
# Epoch 815/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 215.8092 - mse: 215.8092 - accuracy: 0.0000e+00 - mae: 11.0805
# Epoch 816/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 227.7185 - mse: 227.7185 - accuracy: 0.0000e+00 - mae: 11.3409
# Epoch 817/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 217.1157 - mse: 217.1157 - accuracy: 0.0000e+00 - mae: 11.7850
# Epoch 818/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 187.3610 - mse: 187.3610 - accuracy: 0.0000e+00 - mae: 10.0190
# Epoch 819/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 166.5908 - mse: 166.5908 - accuracy: 0.0000e+00 - mae: 9.8777
# Epoch 820/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 216.7015 - mse: 216.7015 - accuracy: 0.0000e+00 - mae: 11.4944
# Epoch 821/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 205.7861 - mse: 205.7861 - accuracy: 0.0000e+00 - mae: 11.0902
# Epoch 822/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 284.6105 - mse: 284.6105 - accuracy: 0.0000e+00 - mae: 12.1745
# Epoch 823/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 216.1118 - mse: 216.1118 - accuracy: 0.0000e+00 - mae: 11.4963
# Epoch 824/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 252.5343 - mse: 252.5343 - accuracy: 0.0000e+00 - mae: 11.8959
# Epoch 825/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 283.9865 - mse: 283.9865 - accuracy: 0.0000e+00 - mae: 12.6623
# Epoch 826/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 316.9455 - mse: 316.9455 - accuracy: 0.0000e+00 - mae: 13.5467
# Epoch 827/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 274.7557 - mse: 274.7557 - accuracy: 0.0000e+00 - mae: 13.0541
# Epoch 828/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 185.8063 - mse: 185.8063 - accuracy: 0.0000e+00 - mae: 10.2996
# Epoch 829/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 223.6429 - mse: 223.6429 - accuracy: 0.0000e+00 - mae: 10.6385
# Epoch 830/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 177.0252 - mse: 177.0252 - accuracy: 0.0000e+00 - mae: 9.8592
# Epoch 831/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 219.2403 - mse: 219.2403 - accuracy: 0.0000e+00 - mae: 10.9249
# Epoch 832/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 222.9688 - mse: 222.9688 - accuracy: 0.0000e+00 - mae: 11.5980
# Epoch 833/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 300.1118 - mse: 300.1118 - accuracy: 0.0000e+00 - mae: 13.4908
# Epoch 834/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 331.5983 - mse: 331.5983 - accuracy: 0.0000e+00 - mae: 14.5207
# Epoch 835/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 280.7960 - mse: 280.7960 - accuracy: 0.0000e+00 - mae: 12.7986
# Epoch 836/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 224.5519 - mse: 224.5519 - accuracy: 0.0000e+00 - mae: 11.3772
# Epoch 837/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 204.1537 - mse: 204.1537 - accuracy: 0.0000e+00 - mae: 10.8818
# Epoch 838/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 304.3024 - mse: 304.3024 - accuracy: 0.0000e+00 - mae: 13.1625
# Epoch 839/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 307.9504 - mse: 307.9504 - accuracy: 0.0000e+00 - mae: 13.5139
# Epoch 840/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 292.4584 - mse: 292.4584 - accuracy: 0.0000e+00 - mae: 12.9556
# Epoch 841/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 302.7637 - mse: 302.7637 - accuracy: 0.0000e+00 - mae: 12.6218
# Epoch 842/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 418.6519 - mse: 418.6519 - accuracy: 0.0000e+00 - mae: 15.4469
# Epoch 843/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 303.1039 - mse: 303.1039 - accuracy: 0.0000e+00 - mae: 12.8864
# Epoch 844/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 304.1273 - mse: 304.1273 - accuracy: 0.0000e+00 - mae: 12.5120
# Epoch 845/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 334.5647 - mse: 334.5647 - accuracy: 0.0000e+00 - mae: 13.5287
# Epoch 846/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 216.0730 - mse: 216.0730 - accuracy: 0.0000e+00 - mae: 10.9894
# Epoch 847/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 178.0071 - mse: 178.0071 - accuracy: 0.0000e+00 - mae: 10.2562
# Epoch 848/3000
# ...
# Epoch 2885/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 70.1390 - mse: 70.1390 - accuracy: 0.0000e+00 - mae: 6.1641
# Epoch 2886/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 93.6777 - mse: 93.6777 - accuracy: 0.0000e+00 - mae: 7.2520
# Epoch 2887/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 77.0879 - mse: 77.0879 - accuracy: 0.0000e+00 - mae: 6.5466
# Epoch 2888/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 75.6867 - mse: 75.6867 - accuracy: 0.0000e+00 - mae: 6.4963
# Epoch 2889/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 59.4160 - mse: 59.4160 - accuracy: 0.0000e+00 - mae: 5.6849
# Epoch 2890/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 86.7415 - mse: 86.7415 - accuracy: 0.0000e+00 - mae: 6.8202
# Epoch 2891/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 133.9385 - mse: 133.9385 - accuracy: 0.0000e+00 - mae: 8.3579
# Epoch 2892/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 155.2505 - mse: 155.2505 - accuracy: 0.0000e+00 - mae: 9.1215
# Epoch 2893/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 98.5333 - mse: 98.5333 - accuracy: 0.0000e+00 - mae: 6.9633
# Epoch 2894/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 97.5657 - mse: 97.5657 - accuracy: 0.0000e+00 - mae: 7.3397
# Epoch 2895/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 95.5906 - mse: 95.5906 - accuracy: 0.0000e+00 - mae: 7.4104
# Epoch 2896/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 139.1535 - mse: 139.1535 - accuracy: 0.0000e+00 - mae: 8.7233
# Epoch 2897/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 82.3406 - mse: 82.3406 - accuracy: 0.0000e+00 - mae: 6.4373
# Epoch 2898/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 142.5359 - mse: 142.5359 - accuracy: 0.0000e+00 - mae: 8.8807
# Epoch 2899/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 120.0173 - mse: 120.0173 - accuracy: 0.0000e+00 - mae: 8.3460
# Epoch 2900/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 78.7722 - mse: 78.7722 - accuracy: 0.0000e+00 - mae: 6.5926
# Epoch 2901/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 81.8814 - mse: 81.8814 - accuracy: 0.0000e+00 - mae: 6.7601
# Epoch 2902/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 78.4126 - mse: 78.4126 - accuracy: 0.0000e+00 - mae: 6.4161
# Epoch 2903/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 93.6417 - mse: 93.6417 - accuracy: 0.0000e+00 - mae: 6.9733
# Epoch 2904/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 153.0743 - mse: 153.0743 - accuracy: 0.0000e+00 - mae: 9.5732
# Epoch 2905/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 103.4657 - mse: 103.4657 - accuracy: 0.0000e+00 - mae: 7.6292
# Epoch 2906/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 127.2238 - mse: 127.2238 - accuracy: 0.0000e+00 - mae: 8.1542
# Epoch 2907/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 77.9594 - mse: 77.9594 - accuracy: 0.0000e+00 - mae: 6.7464
# Epoch 2908/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 90.3638 - mse: 90.3638 - accuracy: 0.0000e+00 - mae: 6.9616
# Epoch 2909/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 97.1661 - mse: 97.1661 - accuracy: 0.0000e+00 - mae: 6.8794
# Epoch 2910/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 118.6924 - mse: 118.6924 - accuracy: 0.0000e+00 - mae: 8.0199
# Epoch 2911/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 96.9238 - mse: 96.9238 - accuracy: 0.0000e+00 - mae: 7.5385
# Epoch 2912/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 120.4503 - mse: 120.4503 - accuracy: 0.0000e+00 - mae: 7.9699
# Epoch 2913/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 81.8932 - mse: 81.8932 - accuracy: 0.0000e+00 - mae: 6.7064
# Epoch 2914/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 91.0966 - mse: 91.0966 - accuracy: 0.0000e+00 - mae: 7.0320
# Epoch 2915/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 97.8764 - mse: 97.8764 - accuracy: 0.0000e+00 - mae: 7.2696
# Epoch 2916/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 162.9133 - mse: 162.9133 - accuracy: 0.0000e+00 - mae: 9.1512
# Epoch 2917/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 148.1208 - mse: 148.1208 - accuracy: 0.0000e+00 - mae: 9.3387
# Epoch 2918/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 92.0282 - mse: 92.0282 - accuracy: 0.0000e+00 - mae: 7.0192
# Epoch 2919/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 120.8119 - mse: 120.8119 - accuracy: 0.0000e+00 - mae: 7.9261
# Epoch 2920/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 101.1417 - mse: 101.1417 - accuracy: 0.0000e+00 - mae: 7.6313
# Epoch 2921/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 113.2266 - mse: 113.2266 - accuracy: 0.0000e+00 - mae: 7.9004
# Epoch 2922/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 106.2658 - mse: 106.2658 - accuracy: 0.0000e+00 - mae: 7.4508
# Epoch 2923/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 87.7459 - mse: 87.7459 - accuracy: 0.0000e+00 - mae: 6.9649
# Epoch 2924/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 127.7862 - mse: 127.7862 - accuracy: 0.0000e+00 - mae: 8.8973
# Epoch 2925/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 107.0207 - mse: 107.0207 - accuracy: 0.0000e+00 - mae: 7.5331
# Epoch 2926/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 133.7738 - mse: 133.7738 - accuracy: 0.0000e+00 - mae: 8.0245
# Epoch 2927/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 144.6185 - mse: 144.6185 - accuracy: 0.0000e+00 - mae: 8.7640
# Epoch 2928/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 382.5992 - mse: 382.5992 - accuracy: 0.0000e+00 - mae: 14.2794
# Epoch 2929/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 249.7381 - mse: 249.7381 - accuracy: 0.0000e+00 - mae: 12.1107
# Epoch 2930/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 181.3844 - mse: 181.3844 - accuracy: 0.0000e+00 - mae: 9.8620
# Epoch 2931/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 209.1450 - mse: 209.1450 - accuracy: 0.0000e+00 - mae: 11.0283
# Epoch 2932/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 187.0330 - mse: 187.0330 - accuracy: 0.0000e+00 - mae: 9.7217
# Epoch 2933/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 200.8340 - mse: 200.8340 - accuracy: 0.0000e+00 - mae: 10.6162
# Epoch 2934/3000
# 6/6 [==============================] - 0s 70ms/step - loss: 144.9758 - mse: 144.9758 - accuracy: 0.0000e+00 - mae: 9.4413
# Epoch 2935/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 144.5245 - mse: 144.5245 - accuracy: 0.0000e+00 - mae: 8.3820
# Epoch 2936/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 165.8651 - mse: 165.8651 - accuracy: 0.0000e+00 - mae: 9.1418
# Epoch 2937/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 89.4736 - mse: 89.4736 - accuracy: 0.0000e+00 - mae: 6.9892
# Epoch 2938/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 111.9997 - mse: 111.9997 - accuracy: 0.0000e+00 - mae: 7.8425
# Epoch 2939/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 109.9575 - mse: 109.9575 - accuracy: 0.0000e+00 - mae: 7.5470
# Epoch 2940/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 136.5071 - mse: 136.5071 - accuracy: 0.0000e+00 - mae: 8.6564
# Epoch 2941/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 101.3527 - mse: 101.3527 - accuracy: 0.0000e+00 - mae: 7.5893
# Epoch 2942/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 88.2696 - mse: 88.2696 - accuracy: 0.0000e+00 - mae: 7.0809
# Epoch 2943/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 119.6479 - mse: 119.6479 - accuracy: 0.0000e+00 - mae: 8.5605
# Epoch 2944/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 117.8420 - mse: 117.8420 - accuracy: 0.0000e+00 - mae: 8.1283
# Epoch 2945/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 87.7735 - mse: 87.7735 - accuracy: 0.0000e+00 - mae: 6.9918
# Epoch 2946/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 125.4096 - mse: 125.4096 - accuracy: 0.0000e+00 - mae: 7.9779
# Epoch 2947/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 126.7951 - mse: 126.7951 - accuracy: 0.0000e+00 - mae: 8.6092
# Epoch 2948/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 147.5862 - mse: 147.5862 - accuracy: 0.0000e+00 - mae: 8.4955
# Epoch 2949/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 117.6963 - mse: 117.6963 - accuracy: 0.0000e+00 - mae: 8.1719
# Epoch 2950/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 89.8849 - mse: 89.8849 - accuracy: 0.0000e+00 - mae: 6.8431
# Epoch 2951/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 81.3314 - mse: 81.3314 - accuracy: 0.0000e+00 - mae: 6.4655
# Epoch 2952/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 76.9672 - mse: 76.9672 - accuracy: 0.0000e+00 - mae: 6.2842
# Epoch 2953/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 78.2116 - mse: 78.2116 - accuracy: 0.0000e+00 - mae: 6.7628
# Epoch 2954/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 91.1523 - mse: 91.1523 - accuracy: 0.0000e+00 - mae: 6.4022
# Epoch 2955/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 96.4598 - mse: 96.4598 - accuracy: 0.0000e+00 - mae: 7.1387
# Epoch 2956/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 120.9034 - mse: 120.9034 - accuracy: 0.0000e+00 - mae: 8.0053
# Epoch 2957/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 119.0047 - mse: 119.0047 - accuracy: 0.0000e+00 - mae: 7.9659
# Epoch 2958/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 88.9912 - mse: 88.9912 - accuracy: 0.0000e+00 - mae: 6.9205
# Epoch 2959/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 75.7163 - mse: 75.7163 - accuracy: 0.0000e+00 - mae: 6.6795
# Epoch 2960/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 83.0287 - mse: 83.0287 - accuracy: 0.0000e+00 - mae: 6.7772
# Epoch 2961/3000
# 6/6 [==============================] - 0s 69ms/step - loss: 100.8395 - mse: 100.8395 - accuracy: 0.0000e+00 - mae: 7.6713
# Epoch 2962/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 82.3549 - mse: 82.3549 - accuracy: 0.0000e+00 - mae: 6.7971
# Epoch 2963/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 109.3551 - mse: 109.3551 - accuracy: 0.0000e+00 - mae: 8.1719
# Epoch 2964/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 105.4590 - mse: 105.4590 - accuracy: 0.0000e+00 - mae: 7.4198
# Epoch 2965/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 121.2934 - mse: 121.2934 - accuracy: 0.0000e+00 - mae: 7.9472
# Epoch 2966/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 91.3393 - mse: 91.3393 - accuracy: 0.0000e+00 - mae: 6.7665
# Epoch 2967/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 88.1440 - mse: 88.1440 - accuracy: 0.0000e+00 - mae: 6.4417
# Epoch 2968/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 189.9013 - mse: 189.9013 - accuracy: 0.0000e+00 - mae: 9.6694
# Epoch 2969/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 158.0928 - mse: 158.0928 - accuracy: 0.0000e+00 - mae: 9.5006
# Epoch 2970/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 150.0544 - mse: 150.0544 - accuracy: 0.0000e+00 - mae: 9.6786
# Epoch 2971/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 110.7603 - mse: 110.7603 - accuracy: 0.0000e+00 - mae: 7.5640
# Epoch 2972/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 132.5981 - mse: 132.5981 - accuracy: 0.0000e+00 - mae: 8.0143
# Epoch 2973/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 102.0899 - mse: 102.0899 - accuracy: 0.0000e+00 - mae: 7.0964
# Epoch 2974/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 151.6986 - mse: 151.6986 - accuracy: 0.0000e+00 - mae: 8.6502
# Epoch 2975/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 123.8338 - mse: 123.8338 - accuracy: 0.0000e+00 - mae: 8.3713
# Epoch 2976/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 176.3608 - mse: 176.3608 - accuracy: 0.0000e+00 - mae: 9.7046
# Epoch 2977/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 184.5075 - mse: 184.5075 - accuracy: 0.0000e+00 - mae: 9.7571
# Epoch 2978/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 121.8054 - mse: 121.8054 - accuracy: 0.0000e+00 - mae: 8.2633
# Epoch 2979/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 99.5161 - mse: 99.5161 - accuracy: 0.0000e+00 - mae: 7.4877
# Epoch 2980/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 93.1885 - mse: 93.1885 - accuracy: 0.0000e+00 - mae: 7.3238
# Epoch 2981/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 101.5667 - mse: 101.5667 - accuracy: 0.0000e+00 - mae: 7.6639
# Epoch 2982/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 63.7187 - mse: 63.7187 - accuracy: 0.0000e+00 - mae: 5.6426
# Epoch 2983/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 60.1903 - mse: 60.1903 - accuracy: 0.0000e+00 - mae: 5.7286
# Epoch 2984/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 77.3026 - mse: 77.3026 - accuracy: 0.0000e+00 - mae: 6.6125
# Epoch 2985/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 106.8036 - mse: 106.8036 - accuracy: 0.0000e+00 - mae: 7.6394
# Epoch 2986/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 79.8011 - mse: 79.8011 - accuracy: 0.0000e+00 - mae: 6.4944
# Epoch 2987/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 88.3433 - mse: 88.3433 - accuracy: 0.0000e+00 - mae: 6.6705
# Epoch 2988/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 73.9142 - mse: 73.9142 - accuracy: 0.0000e+00 - mae: 6.6236
# Epoch 2989/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 77.0891 - mse: 77.0891 - accuracy: 0.0000e+00 - mae: 6.4819
# Epoch 2990/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 81.6117 - mse: 81.6117 - accuracy: 0.0000e+00 - mae: 6.4852
# Epoch 2991/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 80.8501 - mse: 80.8501 - accuracy: 0.0000e+00 - mae: 6.4502
# Epoch 2992/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 99.9044 - mse: 99.9044 - accuracy: 0.0000e+00 - mae: 7.1682
# Epoch 2993/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 80.6756 - mse: 80.6756 - accuracy: 0.0000e+00 - mae: 6.6122
# Epoch 2994/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 93.1390 - mse: 93.1390 - accuracy: 0.0000e+00 - mae: 6.9829
# Epoch 2995/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 91.4787 - mse: 91.4787 - accuracy: 0.0000e+00 - mae: 6.9455
# Epoch 2996/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 67.0331 - mse: 67.0331 - accuracy: 0.0000e+00 - mae: 5.8931
# Epoch 2997/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 82.6672 - mse: 82.6672 - accuracy: 0.0000e+00 - mae: 6.9335
# Epoch 2998/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 69.0580 - mse: 69.0580 - accuracy: 0.0000e+00 - mae: 6.1418
# Epoch 2999/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 109.9696 - mse: 109.9696 - accuracy: 0.0000e+00 - mae: 7.8900
# Epoch 3000/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 117.3202 - mse: 117.3202 - accuracy: 0.0000e+00 - mae: 8.1291

# %%
import smtplib, ssl

port = 465  # For SSL
smtp_server = "smtp.gmail.com"
sender_email = "nuowen0612@gmail.com"  # Enter your address
receiver_email = "nuowen.lei@concordacademy.org"  # Enter receiver address
password = 'zbhnzczsfxnailzj'
message = """\
Subject: IT FINISHED RUNNING

GO UPSTAIRS"""

context = ssl.create_default_context()
with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message)
