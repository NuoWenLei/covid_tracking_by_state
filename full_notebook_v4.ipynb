# %%
import json, requests
url_format = 'https://raw.githubusercontent.com/NuoWenLei/covid_tracking_by_state/main/state_data/alabama.csv'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36"}
r = requests.get('https://raw.githubusercontent.com/NuoWenLei/covid_tracking_by_state/main/state_name_list.json', headers=headers)
r.text
# Out:
# '["alabama", "alaska", "american-samoa", "arizona", "arkansas", "california", "colorado", "connecticut", "delaware", "district-of-columbia", "florida", "georgia", "guam", "hawaii", "idaho", "illinois", "indiana", "iowa", "kansas", "kentucky", "louisiana", "maine", "maryland", "massachusetts", "michigan", "minnesota", "mississippi", "missouri", "montana", "nebraska", "nevada", "new-hampshire", "new-jersey", "new-mexico", "new-york", "north-carolina", "north-dakota", "northern-mariana-islands", "ohio", "oklahoma", "oregon", "pennsylvania", "puerto-rico", "rhode-island", "south-carolina", "south-dakota", "tennessee", "texas", "us-virgin-islands", "utah", "vermont", "virginia", "washington", "west-virginia", "wisconsin", "wyoming"]'

# %%
state_names = json.loads(r.text)

# %% [markdown]
# # Data Cleaning

# %%
from io import StringIO
import pandas as pd, numpy as np
state_pandas_dict_raw = {}

for state in state_names:
    print(state)
    r = requests.get('https://raw.githubusercontent.com/NuoWenLei/covid_tracking_by_state/main/state_data/{}.csv'.format(state), headers=headers)
    state_pandas_dict_raw[state] = pd.read_csv(StringIO(r.text))
# Out:
# alabama
# alaska
# american-samoa
# arizona
# arkansas
# california
# colorado
# connecticut
# delaware
# district-of-columbia
# florida
# georgia
# guam
# hawaii
# idaho
# illinois
# indiana
# iowa
# kansas
# kentucky
# louisiana
# maine
# maryland
# massachusetts
# michigan
# minnesota
# mississippi
# missouri
# montana
# nebraska
# nevada
# new-hampshire
# new-jersey
# new-mexico
# new-york
# north-carolina
# north-dakota
# northern-mariana-islands
# ohio
# oklahoma
# oregon
# pennsylvania
# puerto-rico
# rhode-island
# south-carolina
# south-dakota
# tennessee
# texas
# us-virgin-islands
# utah
# vermont
# virginia
# washington
# west-virginia
# wisconsin
# wyoming

# %%
state_pandas_dict_raw[state_names[0]]
# Out:
#            date state  ...  totalTestsViral  totalTestsViralIncrease
# 0    2021-03-04    AL  ...              NaN                        0
# 1    2021-03-03    AL  ...              NaN                        0
# 2    2021-03-02    AL  ...              NaN                        0
# 3    2021-03-01    AL  ...              NaN                        0
# 4    2021-02-28    AL  ...              NaN                        0
# ..          ...   ...  ...              ...                      ...
# 358  2020-03-11    AL  ...              NaN                        0
# 359  2020-03-10    AL  ...              NaN                        0
# 360  2020-03-09    AL  ...              NaN                        0
# 361  2020-03-08    AL  ...              NaN                        0
# 362  2020-03-07    AL  ...              NaN                        0
#
# [363 rows x 41 columns]

# %%
# find bad columns that is all nan
import matplotlib.pyplot as plt, seaborn as sns
state_pandas_dict = {}
nan_columns = []
all_columns = state_pandas_dict_raw[state].columns.values
must_columns = [i for i in all_columns if 'Increase' in i] + ['deathConfirmed', 'death']
good_states = []
print(must_columns)
for i, state in enumerate(state_names):
    state_pandas_dict[state] = state_pandas_dict_raw[state].drop(['state', 'date'], axis=1).astype('float64').fillna(0.0)
    print(state_pandas_dict[state].shape)
    for col in must_columns:
        if state_pandas_dict_raw[state][state_pandas_dict_raw[state][col].notna()].shape[0] < 200:
            print('State {} skipped due to insufficient data'.format(state))
            break
    else:
        good_states.append(state)
        for col in state_pandas_dict[state].columns.values:
            if state_pandas_dict[state][col].sum() == 0:
                if col not in nan_columns:
                    nan_columns.append(col)
print(len(nan_columns))
# Out:
# ['deathIncrease', 'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease', 'totalTestEncountersViralIncrease', 'totalTestResultsIncrease', 'totalTestsPeopleViralIncrease', 'totalTestsViralIncrease', 'deathConfirmed', 'death']
# (363, 39)
# (364, 39)
# (354, 39)
# State american-samoa skipped due to insufficient data
# (366, 39)
# (364, 39)
# State arkansas skipped due to insufficient data
# (366, 39)
# State california skipped due to insufficient data
# (366, 39)
# (370, 39)
# (364, 39)
# (365, 39)
# State district-of-columbia skipped due to insufficient data
# (401, 39)
# State florida skipped due to insufficient data
# (366, 39)
# State georgia skipped due to insufficient data
# (354, 39)
# State guam skipped due to insufficient data
# (366, 39)
# (363, 39)
# (366, 39)
# (372, 39)
# (364, 39)
# State iowa skipped due to insufficient data
# (364, 39)
# State kansas skipped due to insufficient data
# (364, 39)
# (363, 39)
# (363, 39)
# (365, 39)
# (408, 39)
# (369, 39)
# (364, 39)
# (363, 39)
# (363, 39)
# State missouri skipped due to insufficient data
# (363, 39)
# State montana skipped due to insufficient data
# (384, 39)
# State nebraska skipped due to insufficient data
# (365, 39)
# State nevada skipped due to insufficient data
# (366, 39)
# State new-hampshire skipped due to insufficient data
# (389, 39)
# (365, 39)
# State new-mexico skipped due to insufficient data
# (368, 39)
# State new-york skipped due to insufficient data
# (366, 39)
# (363, 39)
# State north-dakota skipped due to insufficient data
# (354, 39)
# State northern-mariana-islands skipped due to insufficient data
# (365, 39)
# (363, 39)
# State oklahoma skipped due to insufficient data
# (366, 39)
# State oregon skipped due to insufficient data
# (367, 39)
# State pennsylvania skipped due to insufficient data
# (354, 39)
# (369, 39)
# State rhode-island skipped due to insufficient data
# (366, 39)
# (363, 39)
# State south-dakota skipped due to insufficient data
# (365, 39)
# (367, 39)
# State texas skipped due to insufficient data
# (354, 39)
# State us-virgin-islands skipped due to insufficient data
# (363, 39)
# State utah skipped due to insufficient data
# (367, 39)
# (403, 39)
# (417, 39)
# (364, 39)
# (367, 39)
# (369, 39)
# State wyoming skipped due to insufficient data
# 31

# %%
# Drop bad columns
for i, state in enumerate(good_states):
    state_pandas_dict[state] = state_pandas_dict[state].drop(nan_columns, axis=1)

# %%
# Rename state columns with their state name included
good_cols = state_pandas_dict[good_states[0]].columns.values
for state in good_states:
    new_cols = ['{} - {}'.format(state, i) for i in good_cols]
    state_pandas_dict[state].columns = new_cols

# %%
state_pandas_dict[good_states[0]].head()
# Out:
#    alabama - death  ...  alabama - totalTestResultsIncrease
# 0          10094.0  ...                              5890.0
# 1          10029.0  ...                              9595.0
# 2           9991.0  ...                              3648.0
# 3           9931.0  ...                              1858.0
# 4           9929.0  ...                              3265.0
#
# [5 rows x 8 columns]

# %%
state_pandas_dict[good_states[0]].shape
# Out:
# (363, 8)

# %%
arr_lengths = []
for state in good_states:
    print('{}: {}'.format(state, state_pandas_dict[state].shape[0]))
    arr_lengths.append(state_pandas_dict[state].shape[0])
min_length = np.array(arr_lengths).min()
min_length
# Out:
# alabama: 363
# alaska: 364
# arizona: 366
# colorado: 366
# connecticut: 370
# delaware: 364
# hawaii: 366
# idaho: 363
# illinois: 366
# indiana: 372
# kentucky: 364
# louisiana: 363
# maine: 363
# maryland: 365
# massachusetts: 408
# michigan: 369
# minnesota: 364
# mississippi: 363
# new-jersey: 389
# north-carolina: 366
# ohio: 365
# puerto-rico: 354
# south-carolina: 366
# tennessee: 365
# vermont: 367
# virginia: 403
# washington: 417
# west-virginia: 364
# wisconsin: 367
# 354

# %%
for state in good_states:
    state_pandas_dict[state] = state_pandas_dict[state].head(min_length)
print(state_pandas_dict[good_states[0]].shape)
# Out:
# (354, 8)

# %% [markdown]
# # Visualize Death Data per State

# %%
death_data = {'date':state_pandas_dict_raw[good_states[0]].head(min_length)['date'].values}
plt.figure()
for state in good_states:
    death_data[state] = state_pandas_dict_raw[state].sort_values('date', ascending=True).head(min_length)['death'].fillna(0).values
death_df = pd.DataFrame(death_data)
fig, ax = plt.subplots()
sns.lineplot(x='date', y='value', hue='variable', data=pd.melt(death_df, ['date']))
plt.legend(title='legend', bbox_to_anchor=(1.05, 1), loc='upper left')
every_nth = 30
for n, label in enumerate(ax.xaxis.get_ticklabels()):
    if n % every_nth != 0:
        label.set_visible(False)
plt.xticks(rotation=-30)
plt.ylabel('deaths')
plt.show()

# %% [markdown]
# # Find Correlation Array

# %% [markdown]
# ## Try With first of state_names

# %%
df_dict_by_col = dict((col, state_pandas_dict[state_names[0]][col].values) for col in state_pandas_dict[state_names[0]].columns.values)

# %%
df_keys = df_dict_by_col.keys()

corr_data = []
for key0 in df_keys:
    key_row = []
    for key1 in df_keys:
        key_row.append(np.corrcoef(df_dict_by_col[key0], df_dict_by_col[key1])[1,0])
    corr_data.append(key_row)
corr_np = np.float64(corr_data)
corr_np
# Out:
# array([[1.        , 0.99628253, 0.51948179, 0.52389465, 0.97544758,
#         0.44213999, 0.93403598, 0.1507257 ],
#        [0.99628253, 1.        , 0.5129809 , 0.56338023, 0.98333664,
#         0.48379468, 0.95902426, 0.18056535],
#        [0.51948179, 0.5129809 , 1.        , 0.42919816, 0.5351837 ,
#         0.45838197, 0.48158829, 0.17382066],
#        [0.52389465, 0.56338023, 0.42919816, 1.        , 0.66935429,
#         0.83935024, 0.69777342, 0.37174191],
#        [0.97544758, 0.98333664, 0.5351837 , 0.66935429, 1.        ,
#         0.57734761, 0.97508886, 0.19486688],
#        [0.44213999, 0.48379468, 0.45838197, 0.83935024, 0.57734761,
#         1.        , 0.6287938 , 0.45762283],
#        [0.93403598, 0.95902426, 0.48158829, 0.69777342, 0.97508886,
#         0.6287938 , 1.        , 0.26102342],
#        [0.1507257 , 0.18056535, 0.17382066, 0.37174191, 0.19486688,
#         0.45762283, 0.26102342, 1.        ]])

# %%
corr_df = pd.DataFrame(corr_np)
corr_df
# Out:
#           0         1         2  ...         5         6         7
# 0  1.000000  0.996283  0.519482  ...  0.442140  0.934036  0.150726
# 1  0.996283  1.000000  0.512981  ...  0.483795  0.959024  0.180565
# 2  0.519482  0.512981  1.000000  ...  0.458382  0.481588  0.173821
# 3  0.523895  0.563380  0.429198  ...  0.839350  0.697773  0.371742
# 4  0.975448  0.983337  0.535184  ...  0.577348  0.975089  0.194867
# 5  0.442140  0.483795  0.458382  ...  1.000000  0.628794  0.457623
# 6  0.934036  0.959024  0.481588  ...  0.628794  1.000000  0.261023
# 7  0.150726  0.180565  0.173821  ...  0.457623  0.261023  1.000000
#
# [8 rows x 8 columns]

# %%
state_pandas_dict[state_names[0]].columns.shape
# Out:
# (8,)

# %%
def get_corr_list(pointers, corr_np):
    ordered_ls_left = [pointers[0]]
    ordered_ls_right = [pointers[1]]
    corr_ls_sum = 0


    visited = set(pointers.copy())
    all_cols = corr_np.shape[0]

    # Find highest unvisited correlated element
    def get_max(p, visits): 
        # print(p)
        s = sorted(list(enumerate(corr_np[p])),key=lambda x: x[1], reverse=True)
        for item in s:
            if item[0] == i or item[0] in visits:
                continue
            return item
        

    while len(visited) < all_cols:
        # print(pointers)
        val = get_max(pointers[0], visited)
        if val is None:
            break
        pointers[0], corr_val = val
        visited.add(pointers[0])
        ordered_ls_left.append(pointers[0])
        corr_ls_sum += corr_val
        
        val = get_max(pointers[1], visited)
        if val is None:
            break
        pointers[1], corr_val = val
        visited.add(pointers[1])
        ordered_ls_right.append(pointers[1])
        corr_ls_sum += corr_val

    ordered_ls = ordered_ls_left + list(reversed(ordered_ls_right))
    print(len(ordered_ls))
    print(corr_ls_sum)
    return ordered_ls, corr_ls_sum

# %%
def get_corr_list_v2(corr_np):
    pointer = 0
    ordered_ls = [0]
    visited = set([0])
    all_cols = corr_np.shape[0]
    corr_val_dict = {}
    def get_max(p, visits): 
        # print(p)
        s = sorted(list(enumerate(corr_np[p])),key=lambda x: x[1], reverse=True)
        for item in s:
            if item[0] == p or item[0] in visits:
                continue
            return item


    while len(visited) < all_cols:
        val = get_max(pointer, visited)
        if val is None:
            break
        new_pointer, corr_val = val
        visited.add(new_pointer)
        ordered_ls.append(new_pointer)
        corr_val_dict['{}-{}'.format(pointer, new_pointer)] = corr_val
        pointer = new_pointer
    #Complete circle by routing last pointer to first pointer, which is 0
    corr_val_dict['{}-{}'.format(pointer, 0)] = corr_np[pointer, 0]


    return corr_val_dict, ordered_ls

# %%
def get_corr_np(df):
    df_dict_by_col = dict((col, df[col].values) for col in df.columns.values)
    df_keys = df_dict_by_col.keys()
    corr_data = []
    for key0 in df_keys:
        key_row = []
        for key1 in df_keys:
            key_row.append(np.corrcoef(df_dict_by_col[key0], df_dict_by_col[key1])[1,0])
        corr_data.append(key_row)
    corr_np = np.float64(corr_data)
    return corr_np

# %%
def corr_list_by_df(df):
    df_dict_by_col = dict((col, df[col].values) for col in df.columns.values)
    df_keys = df_dict_by_col.keys()
    corr_data = []
    for key0 in df_keys:
        key_row = []
        for key1 in df_keys:
            key_row.append(np.corrcoef(df_dict_by_col[key0], df_dict_by_col[key1])[1,0])
        corr_data.append(key_row)
    corr_np = np.float64(corr_data)
    all_ordered_ls = []
    corr_sum_list = []
    for i in range(corr_np.shape[0]):
        for j in range(i+1, corr_np.shape[1]):
            ls, corr_sum = get_corr_list([i, j], corr_np)
            all_ordered_ls.append(ls)
            corr_sum_list.append(corr_sum)
    corr_sum_np = np.array(corr_sum_list)
    best_ordered_ls = all_ordered_ls[np.argmax(corr_sum_np)]
    print(np.max(corr_sum_np))
    print(best_ordered_ls)
    return best_ordered_ls, corr_np

# %%
# Create full df by combining data for all 
full_df = state_pandas_dict[good_states[0]].copy()
for state in good_states[1:]:
    for col in state_pandas_dict[state].columns.values:
        full_df[col] = state_pandas_dict[state][col].values
full_df.shape
# Out:
# (354, 232)

# %%
full_order_dict, circle_order = get_corr_list_v2(get_corr_np(full_df))

# %%
circle_order
# Out:
# [0,
#  1,
#  16,
#  17,
#  176,
#  177,
#  136,
#  94,
#  142,
#  190,
#  126,
#  230,
#  166,
#  70,
#  38,
#  102,
#  198,
#  118,
#  78,
#  222,
#  30,
#  56,
#  57,
#  172,
#  169,
#  168,
#  110,
#  158,
#  206,
#  150,
#  214,
#  46,
#  22,
#  182,
#  185,
#  156,
#  204,
#  80,
#  81,
#  152,
#  153,
#  140,
#  4,
#  188,
#  212,
#  225,
#  224,
#  76,
#  28,
#  124,
#  12,
#  132,
#  68,
#  60,
#  14,
#  134,
#  86,
#  54,
#  52,
#  48,
#  49,
#  184,
#  217,
#  216,
#  220,
#  164,
#  8,
#  84,
#  44,
#  36,
#  116,
#  148,
#  72,
#  73,
#  108,
#  128,
#  129,
#  64,
#  24,
#  25,
#  65,
#  105,
#  104,
#  40,
#  41,
#  112,
#  32,
#  145,
#  144,
#  113,
#  89,
#  88,
#  201,
#  200,
#  208,
#  92,
#  180,
#  20,
#  97,
#  96,
#  100,
#  196,
#  192,
#  120,
#  121,
#  161,
#  160,
#  6,
#  62,
#  137,
#  174,
#  33,
#  228,
#  155,
#  3,
#  187,
#  219,
#  83,
#  163,
#  75,
#  131,
#  29,
#  69,
#  227,
#  11,
#  59,
#  77,
#  221,
#  109,
#  211,
#  99,
#  205,
#  203,
#  43,
#  107,
#  106,
#  115,
#  147,
#  35,
#  114,
#  146,
#  34,
#  37,
#  125,
#  127,
#  171,
#  167,
#  71,
#  79,
#  31,
#  223,
#  159,
#  111,
#  207,
#  119,
#  103,
#  231,
#  61,
#  229,
#  13,
#  133,
#  135,
#  165,
#  85,
#  157,
#  181,
#  183,
#  197,
#  117,
#  149,
#  45,
#  101,
#  218,
#  5,
#  141,
#  139,
#  179,
#  19,
#  21,
#  23,
#  47,
#  189,
#  191,
#  9,
#  193,
#  209,
#  63,
#  7,
#  58,
#  226,
#  39,
#  186,
#  82,
#  154,
#  2,
#  18,
#  138,
#  98,
#  195,
#  91,
#  90,
#  93,
#  95,
#  130,
#  27,
#  123,
#  67,
#  66,
#  26,
#  122,
#  194,
#  170,
#  213,
#  173,
#  199,
#  55,
#  53,
#  51,
#  178,
#  202,
#  42,
#  210,
#  74,
#  215,
#  151,
#  143,
#  87,
#  15,
#  10,
#  162,
#  50,
#  175]

# %%
def best_ord_from_circle(d, circle):
    items = sorted(d.items(), key=lambda x: x[1], reverse=True)
    start, end = items[-1][0].split('-')
    start_point, end_point = circle.index(int(start)), circle.index(int(end))

    if end_point < start_point:
        return circle
    return list(reversed(circle[:circle.index(start)+1])) + circle[circle.index(end):]

# %%
full_order_v2 = best_ord_from_circle(full_order_dict, circle_order)
len(full_order_v2)
# Out:
# 232

# %%
# Manually Entering Here because running the function takes too long
full_order = [28, 124, 224, 225, 68, 30, 78, 222, 182, 185, 156, 184, 118, 84, 8, 76, 164, 220, 216, 217, 44, 36, 96, 97, 100, 196, 80, 81, 152, 153, 136, 94, 142, 190, 62, 6, 200, 201, 208, 137, 88, 89, 104, 105, 41, 40, 121, 120, 148, 160, 20, 12, 48, 49, 52, 119, 83, 163, 75, 219, 187, 3, 155, 99, 43, 107, 149, 197, 181, 183, 47, 111, 79, 77, 221, 109, 45, 165, 27, 123, 67, 66, 26, 130, 85, 223, 186, 218, 101, 157, 154, 18, 82, 2, 138, 98, 58, 173, 9, 193, 191, 189, 135, 226, 194, 74, 162, 151, 178, 202, 115, 114, 175, 210, 143, 50, 42, 215, 10, 15, 87, 7, 63, 51, 53, 55, 199, 39, 170, 125, 127, 95, 93, 90, 91, 122, 37, 34, 146, 147, 106, 35, 195, 117, 213, 207, 103, 209, 139, 141, 5, 61, 171, 231, 229, 133, 13, 59, 11, 131, 227, 69, 29, 31, 167, 71, 159, 23, 21, 19, 179, 33, 113, 112, 174, 145, 144, 32, 203, 211, 205, 192, 116, 161, 72, 73, 25, 65, 64, 24, 129, 128, 108, 92, 177, 176, 17, 16, 1, 0, 212, 204, 180, 22, 14, 134, 214, 206, 198, 102, 38, 169, 168, 54, 86, 230, 126, 166, 70, 110, 158, 150, 46, 140, 4, 188, 56, 57, 172, 60, 228, 132]

# %%
#full_order, full_corr = corr_list_by_df(full_df)

# %%
test_order, test_corr = corr_list_by_df(state_pandas_dict['alabama'])
# Out:
# 8
# 4.119440919647699
# 8
# 4.160380490760433
# 8
# 4.24397033141963
# 8
# 4.050366399826602
# 8
# 4.312949954532416
# 8
# 3.998920208754184
# 8
# 4.680879255423979
# 8
# 4.135392208751277
# 8
# 4.236081277433167
# 8
# 4.010880817841161
# 8
# 4.305060900545953
# 8
# 3.959434626768743
# 8
# 4.672990201437514
# 8
# 4.243970331419631
# 8
# 4.000770338509906
# 8
# 4.312949954532416
# 8
# 3.846917672464898
# 8
# 4.509549363271225
# 8
# 4.080077193362879
# 8
# 3.873299462086321
# 8
# 3.937387954743997
# 8
# 4.125174009581941
# 8
# 4.297248037975223
# 8
# 4.013405535677349
# 8
# 4.63982637505258
# 8
# 4.016973505712936
# 8
# 4.217180694992925
# 8
# 4.680879255423979
# 4.680879255423979
# [0, 1, 4, 6, 2, 3, 5, 7]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
full_np = scaler.fit_transform(full_df)

# %%
test_full_df = pd.DataFrame(full_np)
img_np = test_full_df[full_order_v2].values

# %%
horizontal_img_np = np.swapaxes(img_np,0,1)

# %%
horizontal_img_np[:, :7]*255
# Out:
# array([[255.        , 253.35793541, 252.39795918, ..., 250.83168219,
#         250.85694472, 249.31593026],
#        [255.        , 253.45454545, 252.42424242, ..., 250.71780303,
#         250.71780303, 249.01136364],
#        [255.        , 253.48748842, 253.03058387, ..., 251.77015755,
#         251.56533828, 250.46246525],
#        ...,
#        [ 14.7404271 ,  14.7404271 ,   0.        , ...,  20.37371134,
#          19.81038292,  20.1859352 ],
#        [  8.36065574,  16.72131148,   8.36065574, ...,   8.36065574,
#          16.72131148,  16.72131148],
#        [ 27.0541631 ,  26.84724789,  27.19498039, ...,  27.48811026,
#          27.28981653,  27.4536244 ]])

# %%
from PIL import Image
im = Image.fromarray(horizontal_img_np[:, :128]*255, 'L')
im.show()

# %%
horizontal_img_np.shape
# Out:
# (232, 354)

# %% [markdown]
# # TODO: Make Predict Values and use time series data to split numpy array into hundreds of 232x128 images

# %%
#full_df.head()
y_val_columns = [i for i in full_df.columns.values if 'deathIncrease' in i]
y_val_columns
# Out:
# ['alabama - deathIncrease',
#  'alaska - deathIncrease',
#  'arizona - deathIncrease',
#  'colorado - deathIncrease',
#  'connecticut - deathIncrease',
#  'delaware - deathIncrease',
#  'hawaii - deathIncrease',
#  'idaho - deathIncrease',
#  'illinois - deathIncrease',
#  'indiana - deathIncrease',
#  'kentucky - deathIncrease',
#  'louisiana - deathIncrease',
#  'maine - deathIncrease',
#  'maryland - deathIncrease',
#  'massachusetts - deathIncrease',
#  'michigan - deathIncrease',
#  'minnesota - deathIncrease',
#  'mississippi - deathIncrease',
#  'new-jersey - deathIncrease',
#  'north-carolina - deathIncrease',
#  'ohio - deathIncrease',
#  'puerto-rico - deathIncrease',
#  'south-carolina - deathIncrease',
#  'tennessee - deathIncrease',
#  'vermont - deathIncrease',
#  'virginia - deathIncrease',
#  'washington - deathIncrease',
#  'west-virginia - deathIncrease',
#  'wisconsin - deathIncrease']

# %%
y_val = np.zeros(full_df.shape[0])
for col in y_val_columns:
    y_val += full_df[col].values
y_val
# Out:
# array([ 668., 1069.,  582.,  559.,  484.,  800.,  967., 1083., 1120.,
#        1042.,  456.,  602.,  807., 1003., 1221.,  980.,  533.,  371.,
#         427., 2008., 3692., 2012., 1670., 1207.,  591.,  543., 1119.,
#        1531., 3163., 1690., 1521.,  760.,  689., 1178., 1469., 1753.,
#        1753., 1819.,  621.,  725., 1609., 1603., 1764., 1762.,  848.,
#         578.,  789., 1563., 1428., 1688., 1811., 1929.,  729.,  869.,
#        1533., 1690., 2066., 1761., 1825.,  846.,  771., 1273.,  933.,
#        1421., 1929., 1767.,  851.,  662.,  931.,  593., 1287., 1673.,
#        1691.,  762.,  765., 1301., 1454., 1894., 1730., 1487.,  720.,
#         729., 1304., 1276., 1664., 1716., 1386.,  655.,  560., 1272.,
#        1280., 1571., 1562., 1452.,  605.,  420.,  664.,  868.,  661.,
#        1267., 1265.,  407.,  462.,  794.,  984., 1173., 1021.,  928.,
#         352.,  352.,  700.,  749.,  571.,  894.,  771.,  343.,  281.,
#         587.,  583.,  605.,  596.,  642.,  210.,  188.,  509.,  481.,
#         515.,  510.,  552.,  234.,  207.,  398.,  465.,  518.,  557.,
#         449.,  257.,  159.,  261.,  377.,  415.,  353.,  378.,  115.,
#         114.,  280.,  302.,  387.,  370.,  311.,  141.,  144.,  332.,
#         368.,  362.,  415.,  366.,  133.,  120.,  301.,  350.,  362.,
#         366.,  396.,  123.,  138.,  305.,  354.,  355.,  424.,  528.,
#         169.,  167.,  291.,  426.,  435.,  487.,  138.,  103.,  161.,
#         321.,  410.,  348.,  379.,  394.,  167.,  224.,  333.,  397.,
#         399.,  568.,  425.,  152.,  198.,  360.,  409.,  434.,  527.,
#         445.,  161.,  210.,  416.,  341.,  389.,  574.,  474.,  154.,
#         254.,  309.,  496.,  498.,  505.,  452.,  167.,  262.,  371.,
#         476.,  570.,  561.,  504.,  209.,  204.,  441.,  491.,  445.,
#         479.,  517.,  160.,  206.,  427.,  380.,  423.,  364.,  353.,
#         143.,  241.,  348.,  384.,  364.,  435.,  552.,  105.,  104.,
#         164.,  293.,  371.,  406.,  337.,  177.,  157.,  316.,  343.,
#         308.,  445.,  418.,  197.,  149.,  404.,  350.,  319.,  430.,
#         430.,  201.,  204.,  431.,  430.,  499.,  536.,  509.,  491.,
#         266.,  450.,  477.,  537.,  598.,  590.,  486.,  401.,  522.,
#         721.,  723.,  850.,  434.,  341.,  425.,  583.,  756.,  667.,
#         950.,  853.,  496.,  546.,  732.,  968., 1105., 1114.,  939.,
#         564.,  619.,  845., 1026., 1169., 1241., 1352.,  608.,  778.,
#         849., 1193., 1406., 1478., 1356.,  714.,  667.,  884., 1191.,
#        1247., 1259., 1339., 1057.,  775., 1003., 1120., 1281., 1419.,
#        1242.,  797.,  799., 1002.,  998., 1032.,  947.,  971.,  599.,
#         581.,  672.,  573.,  594.,  493.,  470.,  270.,  210.,  254.,
#         218.,  168.,  120.,  105.,   88.,   57.,   40.,   37.,   29.,
#          16.,   14.,   17.])

# %%
y_val.shape
# Out:
# (354,)

# %%
TIME_LENGTH = 128
TIME_TEST_LENGTH = 1
def get_x_y(data, predict_vals, batch_size, test_length):
    total_length = data.shape[1]
    useable_starts = total_length - test_length - batch_size
    images = []
    y = []
    for i in range(0, useable_starts):
        images.append(data[:, i:i+batch_size])
        y.append(predict_vals[i+batch_size:i+batch_size+test_length])
    images_np = np.array(images)
    return images_np.reshape((images_np.shape[0], images_np.shape[1], images_np.shape[2], 1)), np.array(y)

imgs, y_values = get_x_y(horizontal_img_np, y_val, TIME_LENGTH, TIME_TEST_LENGTH)
print(imgs.shape)
print(y_values.shape)
# Out:
# (225, 232, 128, 1)
# (225, 1)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Conv2D, Dense, LSTM, SimpleRNN, AveragePooling2D, Flatten, Dropout
from tensorflow.keras.models import Model, Sequential

X_train, X_test, y_train, y_test = train_test_split(imgs, y_values, train_size=0.8, random_state=0)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (180, 232, 128, 1) (45, 232, 128, 1) (180, 1) (45, 1)

# %%
def get_corr_img_cnn_model(feature_length, time_length, pred_length):
    model = Sequential()
    model.add(Conv2D(128, (3,3), input_shape=(feature_length, time_length, 1), padding='same', activation='relu'))
    model.add(AveragePooling2D())
    model.add(Dropout(0.3))
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(AveragePooling2D())
    model.add(Dropout(0.3))
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(pred_length, activation='relu'))
    model.compile(
        loss='mse',
        optimizer='adam',
        metrics=['mse', 'mae']
    )
    print(model.summary())
    return model

model = get_corr_img_cnn_model(X_train.shape[1], TIME_LENGTH, TIME_TEST_LENGTH)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 232, 128, 128)     1280
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 116, 64, 128)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 116, 64, 128)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 116, 64, 64)       73792
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 58, 32, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 58, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 118784)            0
# _________________________________________________________________
# dense (Dense)                (None, 100)               11878500
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 11,953,673
# Trainable params: 11,953,673
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(X_train, y_train, epochs=3000)
# Out:
# Epoch 1/3000
# 6/6 [==============================] - 35s 209ms/step - loss: 313011.0446 - mse: 313011.0446 - mae: 443.1186
# Epoch 2/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 218476.6384 - mse: 218476.6384 - mae: 363.6105
# Epoch 3/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 176480.9174 - mse: 176480.9174 - mae: 290.5319
# Epoch 4/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 132679.5312 - mse: 132679.5312 - mae: 246.3786
# Epoch 5/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 136849.1071 - mse: 136849.1071 - mae: 305.5272
# Epoch 6/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 118829.3996 - mse: 118829.3996 - mae: 235.7978
# Epoch 7/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 103816.8482 - mse: 103816.8482 - mae: 228.5224
# Epoch 8/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 117060.1239 - mse: 117060.1239 - mae: 268.1654
# Epoch 9/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 100371.4464 - mse: 100371.4464 - mae: 215.3277
# Epoch 10/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 99859.7388 - mse: 99859.7388 - mae: 242.8785
# Epoch 11/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 96244.5112 - mse: 96244.5112 - mae: 215.3793
# Epoch 12/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 95420.6964 - mse: 95420.6964 - mae: 221.9850
# Epoch 13/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 99043.1228 - mse: 99043.1228 - mae: 243.3914
# Epoch 14/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 76302.0848 - mse: 76302.0848 - mae: 194.3197
# Epoch 15/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 78926.2366 - mse: 78926.2366 - mae: 202.4854
# Epoch 16/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 87250.0000 - mse: 87250.0000 - mae: 216.3461
# Epoch 17/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 79559.4263 - mse: 79559.4263 - mae: 207.9774
# Epoch 18/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 73616.1010 - mse: 73616.1010 - mae: 203.3424
# Epoch 19/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 82439.3058 - mse: 82439.3058 - mae: 211.9181
# Epoch 20/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 67354.8890 - mse: 67354.8890 - mae: 187.8351
# Epoch 21/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 65846.1975 - mse: 65846.1975 - mae: 187.8581
# Epoch 22/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 65278.3209 - mse: 65278.3209 - mae: 191.6330
# Epoch 23/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 55007.3878 - mse: 55007.3878 - mae: 176.0087
# Epoch 24/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 57086.4916 - mse: 57086.4916 - mae: 183.9058
# Epoch 25/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 50223.3811 - mse: 50223.3811 - mae: 173.9533
# Epoch 26/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 48253.3438 - mse: 48253.3438 - mae: 170.6777
# Epoch 27/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 41046.1641 - mse: 41046.1641 - mae: 164.4718
# Epoch 28/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 34433.4141 - mse: 34433.4141 - mae: 149.7366
# Epoch 29/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 29889.1228 - mse: 29889.1228 - mae: 132.8987
# Epoch 30/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 28475.5098 - mse: 28475.5098 - mae: 136.9400
# Epoch 31/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 28544.3926 - mse: 28544.3926 - mae: 137.3478
# Epoch 32/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 24057.1272 - mse: 24057.1272 - mae: 120.9164
# Epoch 33/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 25154.0466 - mse: 25154.0466 - mae: 128.6304
# Epoch 34/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 20260.4079 - mse: 20260.4079 - mae: 114.2321
# Epoch 35/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 22103.1864 - mse: 22103.1864 - mae: 117.8478
# Epoch 36/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 26863.5184 - mse: 26863.5184 - mae: 133.0218
# Epoch 37/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 22599.3248 - mse: 22599.3248 - mae: 122.9998
# Epoch 38/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 22514.3937 - mse: 22514.3937 - mae: 123.1360
# Epoch 39/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 20739.8002 - mse: 20739.8002 - mae: 115.4285
# Epoch 40/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 25281.9559 - mse: 25281.9559 - mae: 128.8613
# Epoch 41/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 23025.8061 - mse: 23025.8061 - mae: 119.9603
# Epoch 42/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 25724.0162 - mse: 25724.0162 - mae: 123.9164
# Epoch 43/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 21922.8027 - mse: 21922.8027 - mae: 119.5976
# Epoch 44/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 23545.6035 - mse: 23545.6035 - mae: 129.5887
# Epoch 45/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 20615.8005 - mse: 20615.8005 - mae: 110.9476
# Epoch 46/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 20588.4587 - mse: 20588.4587 - mae: 116.0113
# Epoch 47/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 22417.2017 - mse: 22417.2017 - mae: 120.9809
# Epoch 48/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 19183.5608 - mse: 19183.5608 - mae: 108.0202
# Epoch 49/3000
# 6/6 [==============================] - 0s 62ms/step - loss: 20868.4707 - mse: 20868.4707 - mae: 116.0253
# Epoch 50/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 23457.1504 - mse: 23457.1504 - mae: 117.9595
# Epoch 51/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 20612.3453 - mse: 20612.3453 - mae: 112.1450
# Epoch 52/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 22101.6582 - mse: 22101.6582 - mae: 123.1994
# Epoch 53/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 21878.7877 - mse: 21878.7877 - mae: 114.6412
# Epoch 54/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 23717.0438 - mse: 23717.0438 - mae: 120.5161
# Epoch 55/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 22248.3677 - mse: 22248.3677 - mae: 126.4883
# Epoch 56/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 21081.6476 - mse: 21081.6476 - mae: 110.2849
# Epoch 57/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 20708.7218 - mse: 20708.7218 - mae: 118.8100
# Epoch 58/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 21254.8683 - mse: 21254.8683 - mae: 110.4999
# Epoch 59/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 22018.0564 - mse: 22018.0564 - mae: 120.7631
# Epoch 60/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 21732.3122 - mse: 21732.3122 - mae: 106.6303
# Epoch 61/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 21769.8937 - mse: 21769.8937 - mae: 116.0435
# Epoch 62/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 20477.5053 - mse: 20477.5053 - mae: 109.9748
# Epoch 63/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 20667.7201 - mse: 20667.7201 - mae: 118.2051
# Epoch 64/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 28515.2821 - mse: 28515.2821 - mae: 131.4420
# Epoch 65/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 23501.6431 - mse: 23501.6431 - mae: 120.9483
# Epoch 66/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 23697.7927 - mse: 23697.7927 - mae: 129.0052
# Epoch 67/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 23148.9196 - mse: 23148.9196 - mae: 114.2966
# Epoch 68/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 21426.0485 - mse: 21426.0485 - mae: 122.1097
# Epoch 69/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 19689.5190 - mse: 19689.5190 - mae: 108.8153
# Epoch 70/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 22792.2550 - mse: 22792.2550 - mae: 120.9785
# Epoch 71/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 21138.8962 - mse: 21138.8962 - mae: 118.5004
# Epoch 72/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 17924.7913 - mse: 17924.7913 - mae: 103.5448
# Epoch 73/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 17206.5823 - mse: 17206.5823 - mae: 99.5756
# Epoch 74/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 21829.3373 - mse: 21829.3379 - mae: 118.9155
# Epoch 75/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 18994.3493 - mse: 18994.3493 - mae: 103.5825
# Epoch 76/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 19128.6685 - mse: 19128.6685 - mae: 107.5564
# Epoch 77/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 19697.4314 - mse: 19697.4314 - mae: 114.1707
# Epoch 78/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 18338.8993 - mse: 18338.8993 - mae: 106.5130
# Epoch 79/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 19064.6133 - mse: 19064.6133 - mae: 105.5614
# Epoch 80/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 16960.1948 - mse: 16960.1948 - mae: 101.8904
# Epoch 81/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 19268.3368 - mse: 19268.3362 - mae: 108.6229
# Epoch 82/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 16154.8563 - mse: 16154.8563 - mae: 92.6640
# Epoch 83/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 18837.9408 - mse: 18837.9408 - mae: 105.5704
# Epoch 84/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 15384.0547 - mse: 15384.0547 - mae: 89.5535
# Epoch 85/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 15087.7506 - mse: 15087.7506 - mae: 99.2239
# Epoch 86/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 15266.4834 - mse: 15266.4837 - mae: 93.5066
# Epoch 87/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 18585.9715 - mse: 18585.9715 - mae: 107.7414
# Epoch 88/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 17584.5540 - mse: 17584.5540 - mae: 108.5067
# Epoch 89/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 12814.0004 - mse: 12814.0004 - mae: 87.0729
# Epoch 90/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 11549.7545 - mse: 11549.7545 - mae: 81.1562
# Epoch 91/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 14948.0406 - mse: 14948.0406 - mae: 91.0522
# Epoch 92/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 11686.1182 - mse: 11686.1182 - mae: 81.8552
# Epoch 93/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 10600.4234 - mse: 10600.4234 - mae: 76.4832
# Epoch 94/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 10963.4775 - mse: 10963.4775 - mae: 78.6326
# Epoch 95/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 13655.4012 - mse: 13655.4012 - mae: 87.2264
# Epoch 96/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 11621.8990 - mse: 11621.8990 - mae: 83.4597
# Epoch 97/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 11221.6676 - mse: 11221.6676 - mae: 78.0990
# Epoch 98/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 11381.8744 - mse: 11381.8744 - mae: 81.7762
# Epoch 99/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 11104.9090 - mse: 11104.9090 - mae: 79.2474
# Epoch 100/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 10452.0826 - mse: 10452.0826 - mae: 75.2191
# Epoch 101/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 9721.8733 - mse: 9721.8733 - mae: 75.1822
# Epoch 102/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 9623.7753 - mse: 9623.7753 - mae: 75.8874
# Epoch 103/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 10220.3573 - mse: 10220.3573 - mae: 77.0499
# Epoch 104/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 8585.9068 - mse: 8585.9068 - mae: 72.0648
# Epoch 105/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 9064.7069 - mse: 9064.7069 - mae: 74.4459
# Epoch 106/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 9387.8185 - mse: 9387.8185 - mae: 72.9161
# Epoch 107/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 9944.3817 - mse: 9944.3817 - mae: 76.2064
# Epoch 108/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 11130.1698 - mse: 11130.1698 - mae: 80.9105
# Epoch 109/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 10266.7780 - mse: 10266.7780 - mae: 79.7698
# Epoch 110/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 8891.5718 - mse: 8891.5718 - mae: 73.2950
# Epoch 111/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 9456.6801 - mse: 9456.6801 - mae: 75.6582
# Epoch 112/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 8167.2883 - mse: 8167.2883 - mae: 70.5118
# Epoch 113/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 9760.6798 - mse: 9760.6798 - mae: 78.1916
# Epoch 114/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 9584.4220 - mse: 9584.4220 - mae: 74.0893
# Epoch 115/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 8598.0410 - mse: 8598.0410 - mae: 72.7110
# Epoch 116/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 7940.9863 - mse: 7940.9863 - mae: 68.8919
# Epoch 117/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 8660.1157 - mse: 8660.1157 - mae: 71.0948
# Epoch 118/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6979.4281 - mse: 6979.4281 - mae: 64.1930
# Epoch 119/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 8427.8699 - mse: 8427.8699 - mae: 72.3569
# Epoch 120/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 8885.3922 - mse: 8885.3922 - mae: 71.4924
# Epoch 121/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 8200.8781 - mse: 8200.8781 - mae: 68.3547
# Epoch 122/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 8363.8667 - mse: 8363.8667 - mae: 70.0602
# Epoch 123/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 7914.7393 - mse: 7914.7393 - mae: 68.2174
# Epoch 124/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 7278.3595 - mse: 7278.3595 - mae: 64.1206
# Epoch 125/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 8023.5190 - mse: 8023.5190 - mae: 67.4657
# Epoch 126/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 8293.6475 - mse: 8293.6475 - mae: 71.5069
# Epoch 127/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 8446.0596 - mse: 8446.0596 - mae: 72.6443
# Epoch 128/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 7309.3897 - mse: 7309.3897 - mae: 63.8871
# Epoch 129/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 8259.2533 - mse: 8259.2533 - mae: 68.5632
# Epoch 130/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 6882.8402 - mse: 6882.8402 - mae: 64.3549
# Epoch 131/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 7311.3380 - mse: 7311.3380 - mae: 67.6294
# Epoch 132/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 6333.8088 - mse: 6333.8088 - mae: 62.8957
# Epoch 133/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 6726.2312 - mse: 6726.2312 - mae: 64.0643
# Epoch 134/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 7176.9696 - mse: 7176.9696 - mae: 66.0114
# Epoch 135/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 7755.5492 - mse: 7755.5492 - mae: 66.1812
# Epoch 136/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 7412.7464 - mse: 7412.7464 - mae: 68.1030
# Epoch 137/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 7763.3917 - mse: 7763.3917 - mae: 68.2493
# Epoch 138/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6891.4715 - mse: 6891.4715 - mae: 65.1238
# Epoch 139/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 7280.1448 - mse: 7280.1448 - mae: 67.7147
# Epoch 140/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 6932.2648 - mse: 6932.2648 - mae: 63.9082
# Epoch 141/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 8631.5063 - mse: 8631.5063 - mae: 74.7056
# Epoch 142/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 10952.5813 - mse: 10952.5813 - mae: 80.4309
# Epoch 143/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 8146.0192 - mse: 8146.0192 - mae: 71.3682
# Epoch 144/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 7543.9690 - mse: 7543.9690 - mae: 66.6392
# Epoch 145/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 7348.6348 - mse: 7348.6348 - mae: 64.3724
# Epoch 146/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 6833.4644 - mse: 6833.4644 - mae: 65.4200
# Epoch 147/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 7235.6828 - mse: 7235.6828 - mae: 66.8981
# Epoch 148/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6387.9097 - mse: 6387.9097 - mae: 63.3863
# Epoch 149/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6295.0088 - mse: 6295.0088 - mae: 61.6976
# Epoch 150/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6992.2577 - mse: 6992.2577 - mae: 64.8624
# Epoch 151/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 5639.5103 - mse: 5639.5103 - mae: 58.9291
# Epoch 152/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 7156.1955 - mse: 7156.1955 - mae: 67.4398
# Epoch 153/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6091.1081 - mse: 6091.1081 - mae: 58.9252
# Epoch 154/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 6570.1346 - mse: 6570.1346 - mae: 62.8946
# Epoch 155/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 6924.5106 - mse: 6924.5106 - mae: 65.5182
# Epoch 156/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 6693.3179 - mse: 6693.3179 - mae: 63.6919
# Epoch 157/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 7256.7961 - mse: 7256.7961 - mae: 65.1681
# Epoch 158/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 6385.7507 - mse: 6385.7507 - mae: 63.0818
# Epoch 159/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6118.5937 - mse: 6118.5937 - mae: 62.0855
# Epoch 160/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 5999.0213 - mse: 5999.0213 - mae: 60.6760
# Epoch 161/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 7026.0592 - mse: 7026.0592 - mae: 65.6311
# Epoch 162/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6321.0943 - mse: 6321.0943 - mae: 62.0476
# Epoch 163/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6940.5152 - mse: 6940.5152 - mae: 64.8378
# Epoch 164/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 8085.0394 - mse: 8085.0394 - mae: 71.8780
# Epoch 165/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 6175.3313 - mse: 6175.3313 - mae: 62.6547
# Epoch 166/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 6116.7677 - mse: 6116.7677 - mae: 60.2783
# Epoch 167/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6081.0641 - mse: 6081.0641 - mae: 60.5156
# Epoch 168/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 6553.4986 - mse: 6553.4986 - mae: 63.9057
# Epoch 169/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6162.4871 - mse: 6162.4871 - mae: 59.8541
# Epoch 170/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5591.0093 - mse: 5591.0093 - mae: 59.5764
# Epoch 171/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 6329.4591 - mse: 6329.4591 - mae: 61.6120
# Epoch 172/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5611.4407 - mse: 5611.4407 - mae: 58.7331
# Epoch 173/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5509.0419 - mse: 5509.0419 - mae: 56.9350
# Epoch 174/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 6424.3730 - mse: 6424.3730 - mae: 62.7578
# Epoch 175/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5425.2949 - mse: 5425.2949 - mae: 56.9106
# Epoch 176/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6116.5464 - mse: 6116.5464 - mae: 62.1767
# Epoch 177/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 7125.1943 - mse: 7125.1943 - mae: 66.8012
# Epoch 178/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5580.9763 - mse: 5580.9763 - mae: 58.6828
# Epoch 179/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5446.5070 - mse: 5446.5070 - mae: 57.6976
# Epoch 180/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5778.5993 - mse: 5778.5993 - mae: 60.3192
# Epoch 181/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5105.3545 - mse: 5105.3545 - mae: 57.3127
# Epoch 182/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5715.3009 - mse: 5715.3009 - mae: 60.8318
# Epoch 183/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5737.5023 - mse: 5737.5023 - mae: 59.5213
# Epoch 184/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 6026.8915 - mse: 6026.8915 - mae: 60.4177
# Epoch 185/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5274.2546 - mse: 5274.2546 - mae: 56.4764
# Epoch 186/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5187.5238 - mse: 5187.5238 - mae: 55.3508
# Epoch 187/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6132.3311 - mse: 6132.3311 - mae: 60.1516
# Epoch 188/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 6947.9522 - mse: 6947.9525 - mae: 63.8257
# Epoch 189/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 5610.8416 - mse: 5610.8416 - mae: 58.2473
# Epoch 190/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5805.7408 - mse: 5805.7408 - mae: 58.5891
# Epoch 191/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5071.3027 - mse: 5071.3027 - mae: 55.4492
# Epoch 192/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4929.1264 - mse: 4929.1264 - mae: 54.4781
# Epoch 193/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5432.3691 - mse: 5432.3691 - mae: 58.2298
# Epoch 194/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5318.7717 - mse: 5318.7717 - mae: 57.3418
# Epoch 195/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 6230.2409 - mse: 6230.2409 - mae: 60.8435
# Epoch 196/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4685.4070 - mse: 4685.4070 - mae: 52.4235
# Epoch 197/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 6323.6332 - mse: 6323.6332 - mae: 60.4260
# Epoch 198/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5568.0928 - mse: 5568.0928 - mae: 59.2124
# Epoch 199/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5329.8864 - mse: 5329.8864 - mae: 58.0028
# Epoch 200/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5888.2896 - mse: 5888.2896 - mae: 56.3361
# Epoch 201/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 4777.6696 - mse: 4777.6696 - mae: 53.5794
# Epoch 202/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4945.1814 - mse: 4945.1814 - mae: 56.0854
# Epoch 203/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5843.6467 - mse: 5843.6467 - mae: 58.7225
# Epoch 204/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5731.8274 - mse: 5731.8274 - mae: 57.9784
# Epoch 205/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 4932.2917 - mse: 4932.2917 - mae: 55.0795
# Epoch 206/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4838.4148 - mse: 4838.4148 - mae: 54.0439
# Epoch 207/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 4196.1612 - mse: 4196.1612 - mae: 48.8305
# Epoch 208/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5543.3594 - mse: 5543.3594 - mae: 58.4348
# Epoch 209/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 5805.2307 - mse: 5805.2307 - mae: 59.7676
# Epoch 210/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 4720.8580 - mse: 4720.8580 - mae: 54.1696
# Epoch 211/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 4825.2293 - mse: 4825.2293 - mae: 53.2292
# Epoch 212/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 4745.1859 - mse: 4745.1859 - mae: 53.2585
# Epoch 213/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 4070.3360 - mse: 4070.3360 - mae: 50.1695
# Epoch 214/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 4977.0353 - mse: 4977.0353 - mae: 53.0827
# Epoch 215/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4538.9673 - mse: 4538.9673 - mae: 53.0223
# Epoch 216/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4918.1538 - mse: 4918.1538 - mae: 54.4479
# Epoch 217/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4690.3315 - mse: 4690.3315 - mae: 53.2251
# Epoch 218/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5308.7221 - mse: 5308.7221 - mae: 55.4641
# Epoch 219/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4599.1288 - mse: 4599.1288 - mae: 52.5925
# Epoch 220/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 4283.9893 - mse: 4283.9893 - mae: 50.5774
# Epoch 221/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4636.9900 - mse: 4636.9900 - mae: 51.9910
# Epoch 222/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4851.0695 - mse: 4851.0695 - mae: 53.1849
# Epoch 223/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5313.9165 - mse: 5313.9165 - mae: 55.5393
# Epoch 224/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4205.8170 - mse: 4205.8170 - mae: 48.6896
# Epoch 225/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 4121.9230 - mse: 4121.9230 - mae: 48.2800
# Epoch 226/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 4066.9373 - mse: 4066.9373 - mae: 49.9719
# Epoch 227/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4437.9816 - mse: 4437.9816 - mae: 48.2820
# Epoch 228/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 3921.7808 - mse: 3921.7808 - mae: 49.4280
# Epoch 229/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4454.2359 - mse: 4454.2359 - mae: 50.1209
# Epoch 230/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4431.4605 - mse: 4431.4605 - mae: 51.4260
# Epoch 231/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 4181.2139 - mse: 4181.2139 - mae: 47.4225
# Epoch 232/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 4657.8073 - mse: 4657.8073 - mae: 51.8118
# Epoch 233/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 4833.0986 - mse: 4833.0986 - mae: 53.1574
# Epoch 234/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 4181.0183 - mse: 4181.0183 - mae: 48.3036
# Epoch 235/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5679.6590 - mse: 5679.6590 - mae: 56.8479
# Epoch 236/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 5197.1472 - mse: 5197.1472 - mae: 54.6650
# Epoch 237/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 4255.4768 - mse: 4255.4768 - mae: 47.7586
# Epoch 238/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4458.8017 - mse: 4458.8017 - mae: 48.8680
# Epoch 239/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4152.5226 - mse: 4152.5226 - mae: 47.3459
# Epoch 240/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 3296.6571 - mse: 3296.6571 - mae: 42.8413
# Epoch 241/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 4137.7981 - mse: 4137.7981 - mae: 46.6779
# Epoch 242/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 3661.2697 - mse: 3661.2697 - mae: 45.3779
# Epoch 243/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 3929.7096 - mse: 3929.7096 - mae: 46.7787
# Epoch 244/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3891.1216 - mse: 3891.1216 - mae: 44.4733
# Epoch 245/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3852.7306 - mse: 3852.7306 - mae: 45.7438
# Epoch 246/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4755.1418 - mse: 4755.1418 - mae: 53.5717
# Epoch 247/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 4435.3371 - mse: 4435.3371 - mae: 52.0977
# Epoch 248/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 3948.8086 - mse: 3948.8086 - mae: 48.0621
# Epoch 249/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3805.9003 - mse: 3805.9003 - mae: 46.3153
# Epoch 250/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3952.7693 - mse: 3952.7693 - mae: 46.2836
# Epoch 251/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3493.9141 - mse: 3493.9141 - mae: 43.0715
# Epoch 252/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3749.1072 - mse: 3749.1072 - mae: 45.1155
# Epoch 253/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 3892.4752 - mse: 3892.4752 - mae: 46.2035
# Epoch 254/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 3510.1774 - mse: 3510.1774 - mae: 42.8669
# Epoch 255/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3490.9962 - mse: 3490.9962 - mae: 43.5309
# Epoch 256/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3627.1016 - mse: 3627.1016 - mae: 44.3262
# Epoch 257/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3039.2251 - mse: 3039.2251 - mae: 40.1447
# Epoch 258/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 4045.3914 - mse: 4045.3914 - mae: 46.6925
# Epoch 259/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3910.8311 - mse: 3910.8311 - mae: 48.7251
# Epoch 260/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4233.3030 - mse: 4233.3030 - mae: 46.5746
# Epoch 261/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 3454.2806 - mse: 3454.2806 - mae: 42.6785
# Epoch 262/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 2928.3088 - mse: 2928.3088 - mae: 39.7060
# Epoch 263/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2784.3143 - mse: 2784.3143 - mae: 37.7697
# Epoch 264/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2785.5678 - mse: 2785.5678 - mae: 38.5640
# Epoch 265/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 3151.4939 - mse: 3151.4939 - mae: 40.7385
# Epoch 266/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 4097.1034 - mse: 4097.1034 - mae: 46.3067
# Epoch 267/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 3346.6431 - mse: 3346.6431 - mae: 43.4055
# Epoch 268/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 3101.1656 - mse: 3101.1656 - mae: 41.6873
# Epoch 269/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2642.5979 - mse: 2642.5979 - mae: 38.2527
# Epoch 270/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3089.5773 - mse: 3089.5773 - mae: 40.9346
# Epoch 271/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2709.8261 - mse: 2709.8261 - mae: 38.5177
# Epoch 272/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 3393.1716 - mse: 3393.1716 - mae: 43.5477
# Epoch 273/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3477.6610 - mse: 3477.6610 - mae: 41.5419
# Epoch 274/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2603.0876 - mse: 2603.0876 - mae: 37.3080
# Epoch 275/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 3170.4258 - mse: 3170.4258 - mae: 41.4869
# Epoch 276/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 3131.6353 - mse: 3131.6353 - mae: 40.3198
# Epoch 277/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3693.8473 - mse: 3693.8473 - mae: 43.0411
# Epoch 278/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 3214.2017 - mse: 3214.2017 - mae: 40.3213
# Epoch 279/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 3537.9321 - mse: 3537.9321 - mae: 45.6276
# Epoch 280/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 3638.9133 - mse: 3638.9133 - mae: 46.9029
# Epoch 281/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2906.4823 - mse: 2906.4823 - mae: 38.7615
# Epoch 282/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 3337.0837 - mse: 3337.0837 - mae: 39.7365
# Epoch 283/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3395.7116 - mse: 3395.7116 - mae: 41.4474
# Epoch 284/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2647.3209 - mse: 2647.3209 - mae: 37.8267
# Epoch 285/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2667.4546 - mse: 2667.4546 - mae: 38.4985
# Epoch 286/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 3068.6109 - mse: 3068.6109 - mae: 39.7925
# Epoch 287/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 3285.9037 - mse: 3285.9037 - mae: 42.6927
# Epoch 288/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 2439.9398 - mse: 2439.9398 - mae: 36.7340
# Epoch 289/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2709.5308 - mse: 2709.5308 - mae: 37.3246
# Epoch 290/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2914.5983 - mse: 2914.5983 - mae: 39.8958
# Epoch 291/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 3054.5075 - mse: 3054.5075 - mae: 40.0689
# Epoch 292/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2969.2409 - mse: 2969.2409 - mae: 41.2891
# Epoch 293/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 3051.9944 - mse: 3051.9944 - mae: 40.9607
# Epoch 294/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 3141.6908 - mse: 3141.6908 - mae: 43.7030
# Epoch 295/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 2601.8893 - mse: 2601.8893 - mae: 37.3840
# Epoch 296/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 3137.6110 - mse: 3137.6110 - mae: 40.5020
# Epoch 297/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2578.5898 - mse: 2578.5898 - mae: 36.3570
# Epoch 298/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 3261.1386 - mse: 3261.1386 - mae: 41.5994
# Epoch 299/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2425.6282 - mse: 2425.6282 - mae: 36.9038
# Epoch 300/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2361.2572 - mse: 2361.2572 - mae: 35.1185
# Epoch 301/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2450.6044 - mse: 2450.6044 - mae: 34.7041
# Epoch 302/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2146.6674 - mse: 2146.6674 - mae: 34.0099
# Epoch 303/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2216.1366 - mse: 2216.1366 - mae: 34.5248
# Epoch 304/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2593.4480 - mse: 2593.4480 - mae: 36.8729
# Epoch 305/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2347.8357 - mse: 2347.8357 - mae: 34.5386
# Epoch 306/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 2206.5127 - mse: 2206.5127 - mae: 33.7129
# Epoch 307/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2642.6758 - mse: 2642.6758 - mae: 34.6059
# Epoch 308/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2213.3204 - mse: 2213.3204 - mae: 33.1345
# Epoch 309/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2424.6499 - mse: 2424.6499 - mae: 35.5009
# Epoch 310/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 2877.0413 - mse: 2877.0413 - mae: 38.3518
# Epoch 311/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 2181.9689 - mse: 2181.9689 - mae: 33.7901
# Epoch 312/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2441.7117 - mse: 2441.7117 - mae: 36.0601
# Epoch 313/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2399.7801 - mse: 2399.7801 - mae: 35.1107
# Epoch 314/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1827.8235 - mse: 1827.8235 - mae: 31.8328
# Epoch 315/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2562.4512 - mse: 2562.4512 - mae: 38.2155
# Epoch 316/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2003.0871 - mse: 2003.0871 - mae: 34.0871
# Epoch 317/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2138.6071 - mse: 2138.6071 - mae: 33.1153
# Epoch 318/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1928.0078 - mse: 1928.0078 - mae: 32.9564
# Epoch 319/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2835.9257 - mse: 2835.9257 - mae: 37.4153
# Epoch 320/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2011.9380 - mse: 2011.9380 - mae: 33.6948
# Epoch 321/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 2115.7991 - mse: 2115.7991 - mae: 32.5316
# Epoch 322/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 2011.8563 - mse: 2011.8563 - mae: 33.8386
# Epoch 323/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2178.8779 - mse: 2178.8779 - mae: 35.1796
# Epoch 324/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2915.3208 - mse: 2915.3208 - mae: 37.3862
# Epoch 325/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 2402.4083 - mse: 2402.4083 - mae: 35.9802
# Epoch 326/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1882.9332 - mse: 1882.9332 - mae: 30.8978
# Epoch 327/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2543.3590 - mse: 2543.3590 - mae: 35.5296
# Epoch 328/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2266.3096 - mse: 2266.3096 - mae: 34.1370
# Epoch 329/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2056.2278 - mse: 2056.2278 - mae: 33.3581
# Epoch 330/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 2054.6218 - mse: 2054.6218 - mae: 32.1830
# Epoch 331/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2516.1708 - mse: 2516.1708 - mae: 35.2577
# Epoch 332/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1821.4277 - mse: 1821.4277 - mae: 32.7958
# Epoch 333/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1952.5348 - mse: 1952.5348 - mae: 31.8230
# Epoch 334/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 2099.9489 - mse: 2099.9489 - mae: 34.0683
# Epoch 335/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2446.1436 - mse: 2446.1436 - mae: 34.5478
# Epoch 336/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2040.0496 - mse: 2040.0496 - mae: 32.8563
# Epoch 337/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2335.2704 - mse: 2335.2704 - mae: 35.7582
# Epoch 338/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2720.3863 - mse: 2720.3863 - mae: 36.8936
# Epoch 339/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1903.0677 - mse: 1903.0677 - mae: 31.7429
# Epoch 340/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1887.9690 - mse: 1887.9690 - mae: 31.3821
# Epoch 341/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 2097.0342 - mse: 2097.0342 - mae: 33.4502
# Epoch 342/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1829.0962 - mse: 1829.0962 - mae: 32.7395
# Epoch 343/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1896.3822 - mse: 1896.3822 - mae: 31.8180
# Epoch 344/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1711.8591 - mse: 1711.8591 - mae: 28.9180
# Epoch 345/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1817.8353 - mse: 1817.8353 - mae: 30.7439
# Epoch 346/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1944.9589 - mse: 1944.9589 - mae: 33.0744
# Epoch 347/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2647.1076 - mse: 2647.1076 - mae: 36.7213
# Epoch 348/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1818.9512 - mse: 1818.9512 - mae: 32.7515
# Epoch 349/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1904.2803 - mse: 1904.2803 - mae: 32.2047
# Epoch 350/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1533.5186 - mse: 1533.5186 - mae: 28.8348
# Epoch 351/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1826.3454 - mse: 1826.3454 - mae: 31.4530
# Epoch 352/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1473.7891 - mse: 1473.7891 - mae: 27.8520
# Epoch 353/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2136.8019 - mse: 2136.8019 - mae: 33.6316
# Epoch 354/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1744.1377 - mse: 1744.1377 - mae: 30.7645
# Epoch 355/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1697.9101 - mse: 1697.9101 - mae: 29.6227
# Epoch 356/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1562.0068 - mse: 1562.0068 - mae: 28.9740
# Epoch 357/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1849.9406 - mse: 1849.9406 - mae: 32.0936
# Epoch 358/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1458.2797 - mse: 1458.2797 - mae: 28.9689
# Epoch 359/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1659.7001 - mse: 1659.7001 - mae: 30.1672
# Epoch 360/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1531.3358 - mse: 1531.3358 - mae: 28.6242
# Epoch 361/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 2427.7330 - mse: 2427.7330 - mae: 37.6690
# Epoch 362/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2361.0808 - mse: 2361.0808 - mae: 36.8804
# Epoch 363/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1786.2111 - mse: 1786.2111 - mae: 30.6171
# Epoch 364/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1987.2311 - mse: 1987.2311 - mae: 32.5705
# Epoch 365/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1782.0218 - mse: 1782.0218 - mae: 30.5503
# Epoch 366/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 1578.2723 - mse: 1578.2723 - mae: 29.6427
# Epoch 367/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1583.9742 - mse: 1583.9742 - mae: 29.8294
# Epoch 368/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 2018.3135 - mse: 2018.3135 - mae: 33.7698
# Epoch 369/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1900.6454 - mse: 1900.6454 - mae: 33.1654
# Epoch 370/3000
# 6/6 [==============================] - 0s 63ms/step - loss: 1643.6889 - mse: 1643.6889 - mae: 30.3558
# Epoch 371/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1540.7685 - mse: 1540.7685 - mae: 28.5865
# Epoch 372/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1674.5271 - mse: 1674.5271 - mae: 29.2124
# Epoch 373/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1606.1664 - mse: 1606.1664 - mae: 28.5417
# Epoch 374/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1207.2237 - mse: 1207.2237 - mae: 24.5957
# Epoch 375/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1302.1603 - mse: 1302.1603 - mae: 26.4093
# Epoch 376/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1575.9972 - mse: 1575.9972 - mae: 29.8033
# Epoch 377/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 1734.4039 - mse: 1734.4039 - mae: 29.9036
# Epoch 378/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1507.0507 - mse: 1507.0507 - mae: 28.7475
# Epoch 379/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1497.0420 - mse: 1497.0420 - mae: 27.7131
# Epoch 380/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 2073.0201 - mse: 2073.0201 - mae: 33.3183
# Epoch 381/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1806.9159 - mse: 1806.9159 - mae: 32.6604
# Epoch 382/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 2196.1953 - mse: 2196.1953 - mae: 34.7012
# Epoch 383/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1422.3815 - mse: 1422.3815 - mae: 26.9043
# Epoch 384/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1416.1507 - mse: 1416.1507 - mae: 26.9508
# Epoch 385/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1434.3631 - mse: 1434.3631 - mae: 28.2529
# Epoch 386/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1599.5379 - mse: 1599.5379 - mae: 29.3223
# Epoch 387/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1344.3670 - mse: 1344.3670 - mae: 26.6078
# Epoch 388/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1466.5974 - mse: 1466.5974 - mae: 28.8816
# Epoch 389/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1265.0603 - mse: 1265.0603 - mae: 26.3439
# Epoch 390/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1234.2772 - mse: 1234.2772 - mae: 26.3365
# Epoch 391/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1506.4750 - mse: 1506.4750 - mae: 28.1262
# Epoch 392/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1453.9171 - mse: 1453.9171 - mae: 29.3899
# Epoch 393/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1376.9391 - mse: 1376.9391 - mae: 26.8421
# Epoch 394/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1455.9177 - mse: 1455.9177 - mae: 27.6969
# Epoch 395/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 1237.9053 - mse: 1237.9053 - mae: 24.8866
# Epoch 396/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1422.8336 - mse: 1422.8336 - mae: 28.1114
# Epoch 397/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1109.1351 - mse: 1109.1351 - mae: 25.0351
# Epoch 398/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1297.8542 - mse: 1297.8542 - mae: 26.3772
# Epoch 399/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1279.8049 - mse: 1279.8049 - mae: 26.1448
# Epoch 400/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1509.0025 - mse: 1509.0025 - mae: 28.4099
# Epoch 401/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1255.1131 - mse: 1255.1131 - mae: 24.6525
# Epoch 402/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1222.0435 - mse: 1222.0435 - mae: 27.6687
# Epoch 403/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1166.3404 - mse: 1166.3404 - mae: 25.3013
# Epoch 404/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1259.4190 - mse: 1259.4190 - mae: 26.3516
# Epoch 405/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1819.4883 - mse: 1819.4883 - mae: 30.7342
# Epoch 406/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1241.9157 - mse: 1241.9157 - mae: 26.1783
# Epoch 407/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1655.6772 - mse: 1655.6772 - mae: 29.8565
# Epoch 408/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1591.0253 - mse: 1591.0253 - mae: 31.0432
# Epoch 409/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1381.1491 - mse: 1381.1491 - mae: 27.6573
# Epoch 410/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1466.6560 - mse: 1466.6560 - mae: 28.0289
# Epoch 411/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1116.5161 - mse: 1116.5161 - mae: 24.1026
# Epoch 412/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1419.4868 - mse: 1419.4868 - mae: 27.8597
# Epoch 413/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1055.3026 - mse: 1055.3026 - mae: 24.4852
# Epoch 414/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 968.7504 - mse: 968.7504 - mae: 23.9021
# Epoch 415/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1036.2475 - mse: 1036.2475 - mae: 24.5859
# Epoch 416/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1557.1761 - mse: 1557.1761 - mae: 29.3060
# Epoch 417/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1072.8551 - mse: 1072.8551 - mae: 23.9382
# Epoch 418/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1044.8799 - mse: 1044.8799 - mae: 24.5715
# Epoch 419/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1125.4678 - mse: 1125.4678 - mae: 25.3486
# Epoch 420/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1088.1038 - mse: 1088.1038 - mae: 23.9203
# Epoch 421/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1106.5864 - mse: 1106.5864 - mae: 26.3943
# Epoch 422/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1289.2671 - mse: 1289.2671 - mae: 27.5097
# Epoch 423/3000
# 6/6 [==============================] - 0s 68ms/step - loss: 973.2165 - mse: 973.2165 - mae: 23.8583
# Epoch 424/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1100.8731 - mse: 1100.8731 - mae: 24.8875
# Epoch 425/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1081.5357 - mse: 1081.5357 - mae: 24.8468
# Epoch 426/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1234.4763 - mse: 1234.4763 - mae: 26.9860
# Epoch 427/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1296.9960 - mse: 1296.9960 - mae: 27.1510
# Epoch 428/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1263.7966 - mse: 1263.7966 - mae: 25.0394
# Epoch 429/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1223.1443 - mse: 1223.1443 - mae: 26.7374
# Epoch 430/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1003.4746 - mse: 1003.4746 - mae: 24.8564
# Epoch 431/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1316.0276 - mse: 1316.0276 - mae: 27.5441
# Epoch 432/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1022.8671 - mse: 1022.8671 - mae: 23.8735
# Epoch 433/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 965.9558 - mse: 965.9558 - mae: 23.9385
# Epoch 434/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 978.5575 - mse: 978.5575 - mae: 23.4168
# Epoch 435/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1026.4524 - mse: 1026.4524 - mae: 23.0077
# Epoch 436/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1051.9362 - mse: 1051.9362 - mae: 24.8795
# Epoch 437/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1222.5299 - mse: 1222.5299 - mae: 27.0315
# Epoch 438/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 921.3243 - mse: 921.3243 - mae: 23.4501
# Epoch 439/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 976.8522 - mse: 976.8522 - mae: 23.4081
# Epoch 440/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1151.2078 - mse: 1151.2078 - mae: 25.4578
# Epoch 441/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1225.2102 - mse: 1225.2102 - mae: 26.7477
# Epoch 442/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1202.8036 - mse: 1202.8036 - mae: 25.9743
# Epoch 443/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1115.7218 - mse: 1115.7218 - mae: 25.8691
# Epoch 444/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1031.0488 - mse: 1031.0488 - mae: 22.9908
# Epoch 445/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1068.3382 - mse: 1068.3382 - mae: 25.1615
# Epoch 446/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 948.5340 - mse: 948.5340 - mae: 23.8063
# Epoch 447/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 997.0196 - mse: 997.0196 - mae: 22.3861
# Epoch 448/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1081.1810 - mse: 1081.1810 - mae: 25.1297
# Epoch 449/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 924.2498 - mse: 924.2498 - mae: 22.9839
# Epoch 450/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 959.0026 - mse: 959.0026 - mae: 23.5324
# Epoch 451/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1376.6580 - mse: 1376.6580 - mae: 28.1092
# Epoch 452/3000
# 6/6 [==============================] - 0s 64ms/step - loss: 1040.5307 - mse: 1040.5307 - mae: 25.0873
# Epoch 453/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1222.6508 - mse: 1222.6508 - mae: 26.9480
# Epoch 454/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 903.5086 - mse: 903.5086 - mae: 23.5964
# Epoch 455/3000
# 6/6 [==============================] - 0s 65ms/step - loss: 1246.4078 - mse: 1246.4078 - mae: 26.6208
# Epoch 456/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 862.4586 - mse: 862.4586 - mae: 22.4088
# Epoch 457/3000
# 6/6 [==============================] - 0s 66ms/step - loss: 1392.5258 - mse: 1392.5258 - mae: 26.4725
# Epoch 458/3000
# 6/6 [==============================] - 0s 69ms/step - loss: 908.1588 - mse: 908.1588 - mae: 23.3090
# Epoch 459/3000
# 6/6 [==============================] - 0s 67ms/step - loss: 1039.6429 - mse: 1039.6429 - mae: 25.0803
# Epoch 460/3000
# 4/6 [===================>..........] - ETA: 0s - loss: 785.9628 - mse: 785.9628 - mae: 20.6234
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-a4b48a8d02ca> in <module>()
# ----> 1 history = model.fit(X_train, y_train, epochs=3000)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
import smtplib, ssl

port = 465  # For SSL
smtp_server = "smtp.gmail.com"
sender_email = "nuowen0612@gmail.com"  # Enter your address
receiver_email = "nuowen.lei@concordacademy.org"  # Enter receiver address
password = 'zbhnzczsfxnailzj'
message = """\
Subject: IT FINISHED RUNNING

GO UPSTAIRS"""

context = ssl.create_default_context()
with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message)

# %%
def get_normal_lstm_model(feature_length, time_length, pred_length, batch_size):
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, stateful=True, batch_size=batch_size, input_shape=(feature_length, time_length)))
    model.add(LSTM(64, return_sequences=False, stateful=True))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(pred_length, activation='relu'))
    model.compile(
        loss='mse',
        optimizer='adam',
        metrics=['mse', 'mae']
    )
    print(model.summary())
    return model

# %%
X_v2, y_v2 = get_x_y(horizontal_img_np, y_val, 128, TIME_TEST_LENGTH)

# %%
X_v2 = X_v2.reshape(X_v2.shape[0], X_v2.shape[1], X_v2.shape[2])
y_v2 = y_v2.reshape(y_v2.shape[0])
print(X_v2.shape, y_v2.shape)
# Out:
# (225, 232, 128) (225,)

# %%
BATCH_SIZE = 15

# %%
model_v2 = get_normal_lstm_model(X_v2.shape[1], TIME_LENGTH, TIME_TEST_LENGTH, BATCH_SIZE)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (15, 232, 128)            131584
# _________________________________________________________________
# lstm_1 (LSTM)                (15, 64)                  49408
# _________________________________________________________________
# dense_2 (Dense)              (15, 100)                 6500
# _________________________________________________________________
# dense_3 (Dense)              (15, 1)                   101
# =================================================================
# Total params: 187,593
# Trainable params: 187,593
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
full_df.shape
# Out:
# (354, 232)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_v2, y_v2, random_state=0, train_size=0.8)

# %%
print(X_train2.shape, X_test2.shape, y_train2.shape, y_test2.shape)
# Out:
# (180, 232, 128) (45, 232, 128) (180,) (45,)

# %%
history = model_v2.fit(X_train2, y_train2, batch_size=BATCH_SIZE, epochs=10)
# Out:
# Epoch 1/10
# 12/12 [==============================] - 2s 26ms/step - loss: 373772.6659 - mse: 373772.6707 - mae: 491.7854
# Epoch 2/10
# 12/12 [==============================] - 0s 19ms/step - loss: 338608.0769 - mse: 338608.0769 - mae: 478.3296
# Epoch 3/10
# 12/12 [==============================] - 0s 18ms/step - loss: 333214.3389 - mse: 333214.3197 - mae: 475.6690
# Epoch 4/10
# 12/12 [==============================] - 0s 18ms/step - loss: 295742.9856 - mse: 295742.9856 - mae: 448.2958
# Epoch 5/10
# 12/12 [==============================] - 0s 19ms/step - loss: 284839.3041 - mse: 284839.3041 - mae: 444.9043
# Epoch 6/10
# 12/12 [==============================] - 0s 19ms/step - loss: 297192.2332 - mse: 297192.2308 - mae: 455.3838
# Epoch 7/10
# 12/12 [==============================] - 0s 19ms/step - loss: 296988.7825 - mse: 296988.7825 - mae: 448.8147
# Epoch 8/10
# 12/12 [==============================] - 0s 19ms/step - loss: 371832.0264 - mse: 371832.0264 - mae: 497.7478
# Epoch 9/10
# 12/12 [==============================] - 0s 19ms/step - loss: 272532.3365 - mse: 272532.3125 - mae: 437.3275
# Epoch 10/10
# 12/12 [==============================] - 0s 18ms/step - loss: 316768.8630 - mse: 316768.8630 - mae: 458.7904

# %% [markdown]
# # Make into category prediction instead of regression

# %%
def split_category(y, num_categories):
  m = np.max(y)
  cutoff = m/num_categories
  categorical_y = []
  for val in y:
    onehot = np.zeros(num_categories)
    for i in range(num_categories):
      if (i*cutoff) <= val <= ((i+1)*cutoff):
        onehot[i] = 1
        categorical_y.append(onehot)
        break
  return np.array(categorical_y)

# %%
from tensorflow.keras.layers import MaxPooling2D

def get_categorical_cnn_model(feature_length, time_length, pred_categories):
    model = Sequential()
    model.add(Conv2D(128, (3,3), input_shape=(feature_length, time_length, 1), padding='same', activation='relu'))
    model.add(MaxPooling2D())
    model.add(Dropout(0.3))
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(MaxPooling2D())
    model.add(Dropout(0.3))
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(MaxPooling2D())
    model.add(Dropout(0.3))
    model.add(Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(MaxPooling2D())
    model.add(Dropout(0.3))
    #TODO: Add Upsampling to create U-net structure
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(pred_categories, activation='softmax'))
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    print(model.summary())
    return model

# %%
NUM_CATEGORIES = 4

X_v3, y_v3_raw = get_x_y(horizontal_img_np, y_val, TIME_LENGTH, TIME_TEST_LENGTH)
y_v3 = split_category(y_v3_raw, NUM_CATEGORIES)
X_train3, X_test3, y_train3, y_test3 = train_test_split(X_v3, y_v3, random_state=0, train_size=0.8)
print(X_train3.shape, X_test3.shape, y_train3.shape, y_test3.shape)
# Out:
# (180, 232, 128, 1) (45, 232, 128, 1) (180, 4) (45, 4)

# %%
model_v3 = get_categorical_cnn_model(X_train3.shape[1], TIME_LENGTH, NUM_CATEGORIES)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_34 (Conv2D)           (None, 232, 128, 128)     1280
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 116, 64, 128)      0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 116, 64, 128)      0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 116, 64, 64)       73792
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 58, 32, 64)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 58, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 29, 16, 64)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 29, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 14, 8, 64)         0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 14, 8, 64)         0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 7168)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 100)               716900
# _________________________________________________________________
# dense_27 (Dense)             (None, 4)                 404
# =================================================================
# Total params: 866,232
# Trainable params: 866,232
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model_v3.fit(X_train3, y_train3, batch_size=1, epochs=80)
# Out:
# Epoch 1/80
# 180/180 [==============================] - 1s 4ms/step - loss: 1.3556 - accuracy: 0.3119
# Epoch 2/80
# 180/180 [==============================] - 1s 4ms/step - loss: 1.0548 - accuracy: 0.4600
# Epoch 3/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.9451 - accuracy: 0.5215
# Epoch 4/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.8903 - accuracy: 0.5203
# Epoch 5/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.8451 - accuracy: 0.4887
# Epoch 6/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.7268 - accuracy: 0.6550
# Epoch 7/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.7289 - accuracy: 0.6574
# Epoch 8/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.8002 - accuracy: 0.5505
# Epoch 9/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.7670 - accuracy: 0.6085
# Epoch 10/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.6950 - accuracy: 0.6572
# Epoch 11/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.6605 - accuracy: 0.6538
# Epoch 12/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.6768 - accuracy: 0.6150
# Epoch 13/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.7331 - accuracy: 0.6658
# Epoch 14/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.6776 - accuracy: 0.6647
# Epoch 15/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.6851 - accuracy: 0.6274
# Epoch 16/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.6183 - accuracy: 0.6890
# Epoch 17/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.7269 - accuracy: 0.6529
# Epoch 18/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.6971 - accuracy: 0.6204
# Epoch 19/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.8270 - accuracy: 0.5742
# Epoch 20/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.6679 - accuracy: 0.6343
# Epoch 21/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.6932 - accuracy: 0.6833
# Epoch 22/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.6360 - accuracy: 0.7199
# Epoch 23/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.6144 - accuracy: 0.7272
# Epoch 24/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.6503 - accuracy: 0.6635
# Epoch 25/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.5922 - accuracy: 0.7497
# Epoch 26/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.5674 - accuracy: 0.7328
# Epoch 27/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.5675 - accuracy: 0.7804
# Epoch 28/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.5494 - accuracy: 0.7745
# Epoch 29/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.4940 - accuracy: 0.7881
# Epoch 30/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.5754 - accuracy: 0.7129
# Epoch 31/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.5640 - accuracy: 0.7800
# Epoch 32/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.5238 - accuracy: 0.7777
# Epoch 33/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.4843 - accuracy: 0.7855
# Epoch 34/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.4394 - accuracy: 0.8011
# Epoch 35/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.3715 - accuracy: 0.8646
# Epoch 36/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.3906 - accuracy: 0.8260
# Epoch 37/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.4369 - accuracy: 0.8193
# Epoch 38/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.3583 - accuracy: 0.8708
# Epoch 39/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.3102 - accuracy: 0.8677
# Epoch 40/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.3732 - accuracy: 0.8320
# Epoch 41/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.2612 - accuracy: 0.8689
# Epoch 42/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.2923 - accuracy: 0.9027
# Epoch 43/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.2880 - accuracy: 0.8780
# Epoch 44/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.2507 - accuracy: 0.8937
# Epoch 45/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.2883 - accuracy: 0.8892
# Epoch 46/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.2229 - accuracy: 0.9160
# Epoch 47/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.2763 - accuracy: 0.8668
# Epoch 48/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.3136 - accuracy: 0.8727
# Epoch 49/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1930 - accuracy: 0.9375
# Epoch 50/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1573 - accuracy: 0.9154
# Epoch 51/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1929 - accuracy: 0.9240
# Epoch 52/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1313 - accuracy: 0.9419
# Epoch 53/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1017 - accuracy: 0.9589
# Epoch 54/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1126 - accuracy: 0.9693
# Epoch 55/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.2094 - accuracy: 0.9225
# Epoch 56/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1379 - accuracy: 0.9513
# Epoch 57/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0831 - accuracy: 0.9794
# Epoch 58/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0979 - accuracy: 0.9822
# Epoch 59/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0813 - accuracy: 0.9747
# Epoch 60/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1679 - accuracy: 0.9480
# Epoch 61/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0467 - accuracy: 0.9840
# Epoch 62/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1651 - accuracy: 0.9628
# Epoch 63/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0389 - accuracy: 0.9795
# Epoch 64/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.2918 - accuracy: 0.9324
# Epoch 65/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1861 - accuracy: 0.9219
# Epoch 66/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0434 - accuracy: 0.9936
# Epoch 67/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0682 - accuracy: 0.9809
# Epoch 68/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0779 - accuracy: 0.9875
# Epoch 69/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0639 - accuracy: 0.9688
# Epoch 70/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0446 - accuracy: 0.9811
# Epoch 71/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0242 - accuracy: 0.9872
# Epoch 72/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0665 - accuracy: 0.9634
# Epoch 73/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0635 - accuracy: 0.9737
# Epoch 74/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0302 - accuracy: 0.9850
# Epoch 75/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0357 - accuracy: 0.9886
# Epoch 76/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0664 - accuracy: 0.9613
# Epoch 77/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0786 - accuracy: 0.9637
# Epoch 78/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0613 - accuracy: 0.9898
# Epoch 79/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1273 - accuracy: 0.9434
# Epoch 80/80
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0273 - accuracy: 0.9972

# %%
model_v3.evaluate(X_test3, y_test3, batch_size=1)
# Out:
# 45/45 [==============================] - 0s 3ms/step - loss: 1.3255 - accuracy: 0.7111
# [1.32553231716156, 0.7111111283302307]

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
import matplotlib.pyplot as plt, seaborn as sns

# %matplotlib inline

history_time = [i for i in range(len(history.history['loss']))]

sns.lineplot(x=history_time, y=history.history['loss'])
